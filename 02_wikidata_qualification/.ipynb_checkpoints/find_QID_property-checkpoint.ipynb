# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#All-wikidata-properties" data-toc-modified-id="All-wikidata-properties-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>All wikidata properties</a></span></li><li><span><a href="#Get-wikidata-ID" data-toc-modified-id="Get-wikidata-ID-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Get wikidata ID</a></span></li><li><span><a href="#Get-properties" data-toc-modified-id="Get-properties-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Get properties</a></span></li><li><span><a href="#Filter-properties" data-toc-modified-id="Filter-properties-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Filter properties</a></span></li></ul></div>

# %% [markdown]
# # All wikidata properties

# %%
## wikidata property lookup table 

# pip install sparqlwrapper
# https://rdflib.github.io/sparqlwrapper/

import sys
from SPARQLWrapper import SPARQLWrapper, JSON

endpoint_url = "https://query.wikidata.org/sparql"

query = """#All properties with descriptions and aliases and types
SELECT ?property ?propertyTypeLabel ?propertyLabel ?propertyDescription ?propertyAltLabel WHERE {
  # ?property wikibase:propertyType ?propertyType.
  SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
  
}
ORDER BY (xsd:integer(STRAFTER(STR(?property), "P")))"""


def get_results(endpoint_url, query):
    user_agent = "WDQS-example Python/%s.%s" % (sys.version_info[0], sys.version_info[1])
    # TODO adjust user agent; see https://w.wiki/CX6
    sparql = SPARQLWrapper(endpoint_url, agent=user_agent)
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    return sparql.query().convert()

# %%
from pandas.io.json import json_normalize

results = get_results(endpoint_url, query)
all_wikidata_properties = json_normalize(results['results']['bindings'])

# get results 
all_wikidata_properties = all_wikidata_properties[['property.value',
                                                   'propertyTypeLabel.value',
                                                   'propertyLabel.value',
                                                   'propertyDescription.value',
                                                   'propertyAltLabel.value']]

all_wikidata_properties.columns = ['property_ID', 'DataType', 'property_name','description','examples']

# change formats
all_wikidata_properties['property_ID'] = all_wikidata_properties['property_ID'].str[31:]
all_wikidata_properties['DataType'] = all_wikidata_properties['DataType'][0][26:]

all_wikidata_properties.head()
# Out:
#   property_ID      DataType       property_name  \
# 0          P6  WikibaseItem  head of government
# 1         P10  WikibaseItem               video
# 2         P14  WikibaseItem        traffic sign
# 3         P15  WikibaseItem           route map
# 4         P16  WikibaseItem      highway system
#
#                                          description  \
# 0  head of the executive power of this town, city...
# 1  relevant video. For images, use the property P...
# 2  graphic symbol describing the item, used at th...
# 3            image of route map at Wikimedia Commons
# 4  system (or specific country specific road type...
#
#                                             examples
# 0  president, chancellor, mayor, prime minister, ...
# 1           animation, media, gif, trailer (Commons)
# 2  highway shield, shield, highway marker, motorw...
# 3  schema, highway map, map of route, metro map, ...
# 4  transport network, network of routes, part of ...

# %%
len(all_wikidata_properties)
# Out:
# 8813

# %% [markdown]
# So as we can see, wikidata has totally 8798 types of properties/relations.

# %% [markdown]
# # Get wikidata ID

# %%
TERM_LIST = '../01_make_matching_list/matching_list.csv'
WIKIDATA_DICT = './wikidata_id.csv'
WIKIDATA_PROPERTIES = './wikidata_properties.txt'

# %%
import pandas as pd 

matching_list = pd.read_csv(TERM_LIST,dtype={'wiki_title': str})

pagetitle_qid_dict = pd.read_csv(WIKIDATA_DICT, delimiter='\t', header=None, index_col=0).to_dict()[1]
matching_list['QID'] = matching_list['wiki_title'].map(pagetitle_qid_dict)

# %%
matching_list
# Out:
#                                                     term annotation  \
# 0                            aperture z-scan experiments    Process
# 1                        1560nm femtosecond laser pulses   Material
# 2                                        optical-chopper   Material
# 3                         vibrational combination states    Process
# 4                                non-radiative processes    Process
# ...                                                  ...        ...
# 40131                                               cd8+  cell_line
# 40132                                      cd29+ t cells  cell_line
# 40133                                       synoviocytes  cell_type
# 40134    antigen-processing and antigen-presenting cells  cell_type
# 40135  antigen-experienced ( memory ) cd8+ t lymphocytes  cell_line
#
#               df wiki_title  QID
# 0      scienceie        NaN  NaN
# 1      scienceie        NaN  NaN
# 2      scienceie        NaN  NaN
# 3      scienceie        NaN  NaN
# 4      scienceie        NaN  NaN
# ...          ...        ...  ...
# 40131     jnlpba        NaN  NaN
# 40132     jnlpba        NaN  NaN
# 40133     jnlpba        NaN  NaN
# 40134     jnlpba        NaN  NaN
# 40135     jnlpba        NaN  NaN
#
# [40136 rows x 5 columns]

# %%
# target titles that we are going to find their QID
titles = matching_list[matching_list.wiki_title.notna() & matching_list.QID.isna()].wiki_title.values
titles
# Out:
# array(['Absorption', 'Partition function', 'Spin', ..., 'All', 'Ie',
#        'PGS'], dtype=object)

# %%
import requests 
import urllib
import re 
from bs4 import BeautifulSoup

def get_wikidata_id(term):
    
    encoded_term = urllib.parse.quote(term)

    url = f"https://en.wikipedia.org/w/api.php?action=query&format=json&prop=pageprops&ppprop=wikibase_item&redirects=1&titles={encoded_term}"
    html = requests.get(url)
    soup = BeautifulSoup(html.text, 'html.parser').get_text()
    
    wikidata_id = re.findall('wikibase_item\"\:\"(.*)?\".*', soup)
    
    if wikidata_id != []:
        return wikidata_id[0]

# %%
# find wikidata ID for all terms
from tqdm import tqdm


not_found = []
for title in tqdm(titles):
    wikidata_id = get_wikidata_id(title)
    if wikidata_id:
        pagetitle_qid_dict.update({title: wikidata_id})
    else:
        not_found.append(title)
# Out:
# 100%|██████████| 1314/1314 [06:15<00:00,  3.50it/s]

# %%
not_found
# Out:
# ['Ω−ωf', 'Value of']

# %%
# remove the entities without wikidata ID
titles = [title for title in titles if title not in not_found]

# %%
# check disambiguation page
def is_disambiguation_page(wikidata_id):
    
    url = "https://www.wikidata.org/wiki/" + wikidata_id
    html = requests.get(url)
    soup = BeautifulSoup(html.text, 'html.parser')
    
    div = soup.find("div", {"class": "wikibase-entitytermsview-heading-description"}).text
    
    return div == 'Wikimedia disambiguation page'

# %%
QIDs = [pagetitle_qid_dict[title] for title in titles]

# %%
# check disambiguation page for list terms
to_remove = []

for title, wikidata_id in tqdm(zip(titles, QIDs)):
    if is_disambiguation_page(wikidata_id):
        to_remove.append(title)
# Out:
# 1312it [02:01, 10.83it/s]

# %%
to_remove
# Out:
# ['Absorption',
#  'Partition function',
#  'Spin',
#  'LES',
#  'DEM (disambiguation)',
#  'D2',
#  'INS',
#  'H2',
#  'MOF',
#  'Approach',
#  'Lagrangian',
#  'Framework',
#  'N2',
#  'CO',
#  'NH 3',
#  'SO2',
#  'Doping',
#  'Reactor',
#  'Pipe',
#  'RCS',
#  'Pipe',
#  'Forcing',
#  'Waves',
#  'Distribution',
#  'Channel',
#  'Fragmentation',
#  'Framework',
#  'CDS',
#  'Gan',
#  'Cell',
#  'Benchmark',
#  'Hamiltonian',
#  'CI',
#  'TI',
#  'Matrix',
#  'Vessel',
#  'Cooling system',
#  'Saft',
#  'Segment',
#  'Radical',
#  'RM',
#  'Flow',
#  'P-box',
#  'Flow',
#  'Carbon unit',
#  'GFR',
#  'XC',
#  'DFT',
#  'Cladding',
#  'DHC',
#  'Cladding',
#  'CI',
#  'Cis',
#  'Query',
#  'Model',
#  'Pore',
#  'Cellular',
#  'Crack',
#  'QED',
#  'Comparative analysis',
#  'FM',
#  'Fe',
#  'Vessel',
#  'Node',
#  'DG',
#  'Susy',
#  'TIS',
#  'TM',
#  'Ingress',
#  'Hooks',
#  'Churn',
#  'Wasi',
#  'Sea bass',
#  'BB',
#  'Rationalization',
#  'Supply',
#  'Feature',
#  'Method',
#  'Ejection',
#  'Pore',
#  'CNTS',
#  'Bulk',
#  'Weakening',
#  'Trapped',
#  'Ferrite',
#  'Evac',
#  'He',
#  'SM',
#  'SM',
#  'Higgs',
#  'Reaction',
#  'Transience',
#  'Mo',
#  'Fe',
#  'Replacement',
#  'Compound',
#  'CA',
#  'SR',
#  'BA',
#  'GA',
#  'GP',
#  'Object',
#  'Lattice',
#  'Lattice model',
#  'Variable',
#  'Speaker',
#  'Monitor',
#  'Pi (disambiguation)',
#  'Reaction',
#  'Dispersion',
#  'Reaction',
#  'Dilution',
#  'Heated',
#  'Framework',
#  'Agent',
#  'Approach',
#  'Roughness',
#  'Platform',
#  'Study',
#  'Incubation',
#  'Cell',
#  'Organic',
#  'Cure (disambiguation)',
#  'Additive',
#  'TGA',
#  'Conductivity',
#  'Modification',
#  'Rail',
#  'Track',
#  'BIN',
#  'DSC',
#  'Aggregation',
#  'Extension',
#  'Localization',
#  'Model',
#  'Pit',
#  'AL',
#  'Pit',
#  'Current',
#  'Survey',
#  'App',
#  'KMS',
#  'Extension',
#  'TEMS',
#  'C60',
#  'Core',
#  'Plenum',
#  'Mix',
#  'Capsule',
#  'Capsule',
#  'Bloom',
#  'Pipeline',
#  'Plasma',
#  'Cluster',
#  'Cluster',
#  'Anomaly',
#  'A5',
#  'ICCP',
#  'Degradation',
#  'Acidification',
#  'PCA',
#  'Recognition',
#  'LPD',
#  'Dope',
#  'Morphology',
#  'Plasma',
#  'Cost function',
#  'Regression',
#  'Parity',
#  'DSMC',
#  'TSH',
#  'LR',
#  'MN',
#  'D2',
#  'CCS',
#  'Fission',
#  'Bubble',
#  'Migration',
#  'Xe',
#  'VU',
#  'Rearrangement',
#  'Charge',
#  'Potential (disambiguation)',
#  'Profile',
#  'Sample',
#  'Sample',
#  'Return',
#  'Plate',
#  'BEM',
#  'AOP',
#  'NB',
#  'TCR',
#  'SPM',
#  'AFM',
#  'AFM',
#  'The System',
#  'Duct',
#  'Identification',
#  'Pods',
#  'OTS',
#  'ECD',
#  'LSM',
#  'Normalization',
#  'FDI',
#  'Sum rule',
#  'Oh',
#  'PAM',
#  'Study',
#  'PG',
#  'ICP',
#  'Lamella',
#  'Iga',
#  'Poisson',
#  'Belle',
#  'Nodal',
#  'Residue',
#  'Threshold',
#  'Tracking',
#  'Weight (disambiguation)',
#  'Convergence',
#  'MLP',
#  'Ann',
#  'ATF',
#  'ODS',
#  'Balance',
#  'Consolidation',
#  'Swelling',
#  'Model',
#  'SPS',
#  'Mold (disambiguation)',
#  'Duct',
#  'LM',
#  'SEM',
#  'Strain',
#  'Ros',
#  'Strand',
#  'DBS',
#  'AA',
#  'Investigation',
#  'Investigation',
#  'Retrieval',
#  'Tube',
#  'Na',
#  'Period',
#  'Yield',
#  'Jetting',
#  'Test',
#  'Tack',
#  'PSA',
#  'Substrate',
#  'ETC',
#  'Block',
#  'Eva',
#  'Interpretation',
#  'SAA',
#  'Hard metal',
#  'Absorption',
#  'Mitigation',
#  'Reflection',
#  'Layer',
#  'Penetration',
#  'Base',
#  'Spectra',
#  'Speaker',
#  'Vad',
#  'Dressing',
#  'Deep Water',
#  'Cox',
#  'PX',
#  'PAS',
#  'Crack',
#  'Permeability',
#  'SDR',
#  'CSM',
#  'Circuit',
#  'Substrate',
#  'Exposure',
#  'Insulator',
#  'Digraph',
#  'Motion tracking',
#  'Splitting',
#  'Sweep',
#  'IRB',
#  'MBR',
#  'MBR',
#  'SOC',
#  'Quality',
#  'Objective',
#  'Galerkin',
#  'CG',
#  'FR',
#  'Mil',
#  'Process',
#  'Composite',
#  'Infection (disambiguation)',
#  'Defect',
#  'Void',
#  'Swelling',
#  'Charm',
#  'Vo',
#  'Oi',
#  'Flow',
#  'Singularity',
#  'Dissociation',
#  'Romp',
#  'Coordination',
#  'Deactivation',
#  'LMS',
#  'CGM',
#  'Alkylamines',
#  'Model',
#  'MD',
#  'Ni',
#  'Element',
#  'Scene',
#  'Classification',
#  'GDC',
#  'Polarization',
#  'Jerks',
#  'SV',
#  'MF',
#  'SA',
#  'Jerk',
#  'Nucleus',
#  'PCA',
#  'B0',
#  'Decay',
#  'Pav',
#  'Inverse',
#  'Roll',
#  'Compound',
#  'SN',
#  'ZN',
#  'AG',
#  'Fib',
#  'CT',
#  'FEM',
#  'Fabrication',
#  'Bubble',
#  'BCC',
#  'Phosphorous',
#  'Transform',
#  'Time scale',
#  'Time scale',
#  'GA',
#  'Imaging',
#  'O2',
#  'Module',
#  'SA',
#  'Scale up',
#  'Response rate',
#  'HPC',
#  'Simple',
#  'Quantization',
#  'Production',
#  'Query',
#  'CRG',
#  'BN',
#  'Clustering',
#  'IAS',
#  'Shell model',
#  'EDS',
#  'Stem',
#  'Tem',
#  'Hybrid',
#  'CA',
#  'Pe',
#  'Stem',
#  'Circ',
#  'ALD',
#  'Functional',
#  'PDES',
#  'Melt',
#  'JPC',
#  'GT',
#  'Graph',
#  'IDS',
#  'Tem',
#  'Poly',
#  'Hema',
#  'FEA',
#  'Shell',
#  'PL',
#  'PL',
#  'Convergence',
#  'EIS',
#  'SEM',
#  'Doping',
#  'Instrument',
#  'Model',
#  'Upper atmosphere',
#  'W/o',
#  'CMC',
#  'Quantitative analysis',
#  'Metalization',
#  'Odes',
#  'Site',
#  'Artifact',
#  'Propagation',
#  'Enrichment',
#  'Phaser',
#  'Mac',
#  'Node',
#  'Pulp',
#  'SLR',
#  'Regression',
#  'Us',
#  'Crossover',
#  'TH',
#  'LR',
#  'Passenger safety',
#  'Composite',
#  'Atomization',
#  'DPD',
#  'Put',
#  'MD',
#  'NTA',
#  'Chamber',
#  'Chambers',
#  'TFM',
#  'Grid',
#  'HPC',
#  'Application',
#  'Virtual server',
#  'NL',
#  'NS',
#  'STL',
#  'Vero',
#  'Dag',
#  'Schmidt',
#  'Shell',
#  'TPA',
#  'RH',
#  'DOS (disambiguation)',
#  'Pill',
#  'Vissim',
#  'Driver',
#  'Deployment',
#  'SNR',
#  'DP',
#  'Mass (disambiguation)',
#  'ENU (disambiguation)',
#  'Termination',
#  'Plane',
#  'Element',
#  'Mola',
#  'Dems',
#  'DEM (disambiguation)',
#  'Inequality',
#  'Surf',
#  'SVM',
#  'Nucleus',
#  'PC',
#  'Interface',
#  'SB',
#  'MSE',
#  'LCS',
#  'Moment',
#  'Critical density',
#  'Buffer',
#  'Buffer',
#  'Transmission',
#  'Imaging',
#  'Dea',
#  'Equivalence theorem',
#  'H0',
#  'LBP',
#  'ER',
#  'Recognition',
#  'Preprocessing',
#  'Batch',
#  'Batch',
#  'SE',
#  'CTF',
#  'PSD',
#  'SPS',
#  'Render',
#  'ROP',
#  'Kernel',
#  'PT',
#  'MGS',
#  'Protocol',
#  'Network',
#  'Segregation',
#  'Phase change',
#  'DM',
#  'Was',
#  'ALD',
#  'AMN',
#  'HD',
#  'Fed',
#  'AT',
#  'ND',
#  'DTD',
#  'APC',
#  'FAP',
#  'AAPC',
#  'JT',
#  'Tremor (disambiguation)',
#  'WT',
#  'DPD',
#  'DDS',
#  'HH',
#  'GH',
#  'Aku',
#  'Eva',
#  'FD',
#  'IDC',
#  'HPC',
#  'DGS',
#  'EMD',
#  'CHS',
#  'As',
#  'CP',
#  'McLeod',
#  'MJD',
#  'XLT',
#  'MED',
#  'FS',
#  'PLS',
#  'Retinal degeneration',
#  'FEO',
#  'PDB',
#  'HMS',
#  'PPK',
#  'Trauma',
#  'WD',
#  'Sudden death',
#  'Ara',
#  'GD',
#  'Macular dystrophy',
#  'AAS',
#  'HPA',
#  'CHM',
#  'NDP',
#  'Duchenne',
#  'WAGR',
#  'MLD',
#  'Xai',
#  'CES',
#  'PG',
#  'GS',
#  'FPC',
#  'TS',
#  'TCD',
#  'LGS',
#  'HBL',
#  'GTD',
#  'Ado',
#  'Norrie',
#  'Junctional epidermolysis bullosa',
#  'DMS',
#  'Ptosis',
#  'CLD',
#  'CRC',
#  'HCP',
#  'Hus',
#  'Depression',
#  'CDM',
#  'HC',
#  'CT',
#  'Error rate',
#  'SVM',
#  'SEAC',
#  'Precision',
#  'Recall',
#  'Go',
#  'NLP',
#  'Classification',
#  'MT',
#  'Whitening',
#  'Cran',
#  'IDE',
#  'Royal',
#  'CDF',
#  'ACL',
#  'European',
#  'ITRC',
#  'MLE',
#  'Multithreading',
#  'RDF',
#  'Planner',
#  'Russian',
#  'Vision',
#  'ELRA',
#  'Springer',
#  'Sensitivity',
#  'Android',
#  'Visualization',
#  'English',
#  'APL',
#  'Feature detection',
#  'American',
#  'Israeli',
#  'Python',
#  'Dutch',
#  'Puma',
#  'Assembly',
#  'Cross-validation',
#  'MSE',
#  'OMR',
#  'OCR',
#  'Classification',
#  'Searching',
#  'ML',
#  'MV',
#  'Map (disambiguation)',
#  'BS',
#  'MA',
#  'DAML',
#  'Oil (disambiguation)',
#  'Normalization',
#  'NLU',
#  'NLG',
#  'PPV',
#  'NPV',
#  'For',
#  'IM',
#  'Bro',
#  'Alexa',
#  'Extraction',
#  'PDL',
#  'LCS',
#  'Regularization',
#  'Paramount',
#  'Sangaree',
#  'KRL',
#  'BMVC',
#  'LTM',
#  'Taxonomy',
#  'Locomotion',
#  'Scheme',
#  'AISB',
#  'DSP',
#  'Audio compression',
#  'Digital',
#  'Process',
#  'MLM',
#  'Surf',
#  'Index',
#  'TN',
#  'TP',
#  'TN',
#  'FP',
#  'FN',
#  'Go',
#  'SMC',
#  'Bandwidth',
#  'LR',
#  'Android',
#  'Acoustic',
#  'Sensitivity',
#  'Specificity',
#  'IAI',
#  'Learning theory',
#  'Cf',
#  'VLDB',
#  'NMT',
#  'CSR',
#  'KDD',
#  'ACM',
#  'ACM',
#  'AAAS',
#  'Indy',
#  'NMF',
#  'Freddy',
#  'School of Computer Science',
#  'RLS',
#  'Gate (disambiguation)',
#  'HMM',
#  'Access',
#  'SAS',
#  'ACL',
#  'EAS',
#  'Baxter',
#  'CGI',
#  'Prosody',
#  'NPS',
#  'HS',
#  'Control',
#  'Facial recognition',
#  'Go',
#  'Word alignment',
#  'SMT',
#  'WSD',
#  'Roc',
#  'HLT',
#  'EM',
#  'Map (disambiguation)',
#  'FPR',
#  'FNR',
#  'Ale (disambiguation)',
#  'Ares (disambiguation)',
#  'ANN',
#  'ERM',
#  'Oscar',
#  'Rotary joint',
#  'ISWC',
#  'UAI',
#  'WSDM',
#  'German',
#  'Sully',
#  'First man or woman',
#  'ABA',
#  'FC',
#  'Kawasaki',
#  'MCC',
#  'Bea',
#  'NER',
#  'QA',
#  'LSI',
#  'Assembly',
#  'Pascal',
#  'Cog',
#  'ASR',
#  'TTS',
#  'TPR',
#  'CP',
#  'LCA',
#  'Cost function',
#  'Tracking',
#  'MARF',
#  'Animal (disambiguation)',
#  'HTK',
#  'Industrial',
#  'Tuning',
#  'WER',
#  'Mandarin',
#  'TNR',
#  'Specificity',
#  'SPC',
#  'Kismet',
#  'VAL',
#  'Recall',
#  'Retrieval',
#  'Web',
#  'SFM',
#  'FIET',
#  'LPC',
#  'NTT',
#  'LDA',
#  'PCA',
#  'French',
#  'HAL',
#  'Loss',
#  'HCA',
#  'VUI',
#  'Nuance',
#  'Columbia',
#  'DAQ',
#  'WSI',
#  'AR',
#  'DAP',
#  'RET',
#  'Broadway',
#  'MLP',
#  'Caffe',
#  'CART',
#  'Orange',
#  'DCG',
#  'Voice recognition',
#  'Babel fish',
#  'Network',
#  'Cling',
#  'Ex Machina',
#  'Hondo',
#  'CCA',
#  'CTC',
#  'LFP',
#  'LP',
#  '.net (disambiguation)',
#  'Summary',
#  'NIPS',
#  '.net (disambiguation)',
#  'Sigmoid',
#  'BBN',
#  'AGV',
#  'J48',
#  'ICCL',
#  'DPD',
#  'BER',
#  'Titan',
#  'Heartstone',
#  'Athletics',
#  'FRS',
#  'HFE2',
#  'PE',
#  'PP',
#  'GI',
#  'Gigantea',
#  'EPL',
#  'Voyager',
#  'Mimas',
#  'Roman',
#  'CLR',
#  'Angelina',
#  'Optica',
#  'SSC',
#  '4S',
#  'Eris',
#  'Mason',
#  'Mercury',
#  'IAP',
#  'Royal Victoria Hospital',
#  'PEP',
#  'OAA',
#  'ASN',
#  'PRO',
#  'ARG',
#  'Rhea',
#  'Triton',
#  'PRA',
#  'LH',
#  'JGI',
#  'WCS',
#  'Irreversible',
#  'No',
#  'BTX',
#  'Cell',
#  'IL-6',
#  'April (disambiguation)',
#  'Matrix',
#  'New',
#  'Horizon (disambiguation)',
#  'FSH',
#  'HR',
#  'IPA',
#  'Caravan',
#  'Ceres',
#  'Quantum theory',
#  'JACS',
#  'Methone',
#  'App',
#  'ELKS',
#  'DPS',
#  'Ogilvie',
#  'AT',
#  'Chinese Physics',
#  'DHPR',
#  'CAQ',
#  'The Patriot',
#  'NAA',
#  'IBA',
#  'Public Service Medal',
#  'Juno',
#  'Camilla',
#  'RN',
#  'EFR',
#  'PRR',
#  'Cassini',
#  'Solar',
#  'Lunar',
#  'PKA',
#  'Transcription',
#  'AIA',
#  'CDK',
#  'Meridian',
#  'Sinope',
#  'The End',
#  'Ni',
#  'PT',
#  'Au',
#  'CPHA',
#  'IPA',
#  'PPA',
#  'A. fragilis',
#  'Fas',
#  'DR',
#  'Ras',
#  'IL-4',
#  'IL-2',
#  'Gymnasium',
#  'Sam',
#  'Environment',
#  'Ros',
#  'BES',
#  'MES',
#  'Doe',
#  'Lost',
#  'Sensorimotor',
#  'KIE',
#  'Royal Academy of Sciences',
#  'Flat Earth Society',
#  'Lunar distance',
#  'Ago',
#  'CO',
#  'FT',
#  'ARA',
#  'Kronos',
#  'SDS',
#  'DOC',
#  'Cosmic',
#  'PHA',
#  'CpG',
#  'KOS',
#  'CCI',
#  'MCA',
#  'IPMS',
#  'BIH',
#  'Europa',
#  'Ganymede',
#  'Specimen',
#  'Tissue',
#  'Varices',
#  'Alveolus',
#  'Focus',
#  'Focal',
#  'Cerebral',
#  'Organ',
#  'Cell',
#  'Central vein',
#  'Cell',
#  'Plasma',
#  'Cerebral',
#  'Nasal',
#  'Sinus',
#  'Tissue',
#  'NCC',
#  'Suture',
#  'Cell',
#  'Lateral',
#  'Coronary',
#  'White cell',
#  'Cervical',
#  'Ventricle',
#  'Plaque',
#  'Oral',
#  'LC',
#  'Cortex',
#  'Serum',
#  'Plasma',
#  'Limb',
#  'MNC',
#  'Ventricle',
#  'Tissue',
#  'Atrium',
#  'Mo',
#  'Mo',
#  'Cellular',
#  'GB',
#  'SCC',
#  'LCC',
#  'LE',
#  'Sample',
#  'Sample',
#  'Body',
#  'PLN',
#  'Sample',
#  'Plaque',
#  'Lumen',
#  'Sacculus',
#  'Sample',
#  'Iris',
#  'ICB',
#  'Ciliary',
#  'Iris',
#  'Fragment',
#  'EC',
#  'Cell',
#  'ML',
#  'Effector cell',
#  'Memory cell',
#  'Nucleus',
#  'Nuclear',
#  'Filament',
#  'FLS',
#  'Ventricle',
#  'Ventricle',
#  'Tubular',
#  'Interstitial',
#  'Fragment',
#  'Specimen',
#  'Trunk',
#  'Inner membrane',
#  'CNS',
#  'Esophageal',
#  'Colon',
#  'Conduit',
#  'Limb',
#  'Ra (disambiguation)',
#  'Ita',
#  'Limb',
#  'Rp',
#  'Cortex',
#  'Left',
#  'Graft',
#  'Spine',
#  'Sera',
#  'WB',
#  'Sarcoid',
#  'WML',
#  'Brachial',
#  'Tympanum',
#  'Cochlear',
#  'Cochlear',
#  'Gut',
#  'Serum',
#  'Graft',
#  'Pelvic limb',
#  'Nucleus',
#  ...]

# %%
len(to_remove)/len(titles)
# Out:
# 1.0

# %%
# # remove disambiguation page from list entities
# for key in to_remove:
#     dict_pagetitle_qid.pop(key)

# %%
pd.DataFrame([(k,v) for k,v in pagetitle_qid_dict.items()]).to_csv(WIKIDATA_DICT, header=None, index=False, sep='\t')

# %% [markdown]
# # Get properties

# %%
import numpy as np

def retrieve_value_P(P):
    for i in range(len(all_wikidata_properties)):
        if P == all_wikidata_properties['property_ID'][i]:
            return all_wikidata_properties['property_name'][i]


def retrieve_value_Q(Q):    
    url = f"https://www.wikidata.org/w/api.php?action=wbgetentities&format=json&props=labels&languages=en&ids={Q}"
    json_response = requests.get(url).json()
    entities = json_response.get('entities')
    
    entity = entities.get(Q)
    if entity:
        labels = entity.get('labels')
        if labels:
            en = labels.get('en')
            if en:
                value = en.get('value')
                return value 


def get_all_ItemProperties(wikidata_item, wikidata_id):
    url = "https://www.wikidata.org/w/api.php?action=wbgetclaims&format=json&entity="+wikidata_id
    json_response = requests.get(url).json()

    properties = [*json_response.get('claims').values()]
    
    res = np.empty(shape=[0, 3])
    
    for p in properties:   
        for d in p: 
            dict_ = d['mainsnak']
        
            # ignore if not a wikibase item
            if dict_['datatype'] != 'wikibase-item' or dict_['snaktype'] != 'value':
                continue 
                
            # replace all the wikidataItem ID by wikidataItem name          
            property_value = retrieve_value_Q(dict_['datavalue']['value']['id'])
            
            if property_value is None:
                continue
            
            # find property value in the previous lookup table
            property_ = retrieve_value_P(dict_['property'])
            
            row_to_append = [wikidata_item, property_, property_value]
  
            res = np.append(res, [row_to_append], 0)  
  
    return res

# %%
get_all_ItemProperties(wikidata_item='algorithm', wikidata_id='Q8366')
# Out:
# array([['algorithm', 'subclass of', 'procedure'],
#        ['algorithm', 'subclass of', 'work'],
#        ['algorithm', 'named after', 'Al-Khwarizmi'],
#        ['algorithm', 'part of', 'computer science'],
#        ['algorithm', 'part of', 'algorithmics'],
#        ['algorithm', 'part of', 'mathematics'],
#        ['algorithm', "topic's main category", 'Category:Algorithms'],
#        ['algorithm', "topic's main template",
#         'Template:Infobox algorithm'],
#        ['algorithm', 'described by source', 'Ottův slovník naučný'],
#        ['algorithm', 'described by source',
#         'The Art of Computer Programming, Volume 1: Fundamental Algorithms, 3rd edition'],
#        ['algorithm', 'described by source', 'Gujin Tushu Jicheng'],
#        ['algorithm', 'on focus list of Wikimedia project',
#         'Wikipedia:Vital articles'],
#        ['algorithm', 'maintained by WikiProject',
#         'WikiProject Computer science'],
#        ['algorithm', 'has quality', 'computational complexity'],
#        ['algorithm', 'has quality', 'algorithmic efficiency'],
#        ['algorithm', 'has quality', 'algorithmic stability']],
#       dtype='<U78')

# %%
# find related pairs for all items in our dictionary
if WIKIDATA_PROPERTIES:
    related_pairs = np.loadtxt('./wikidata_properties.txt', delimiter='\t', dtype='str')
else:
    related_pairs = np.empty(shape=[0, 3])

# %%
for item, Qid in tqdm(pagetitle_qid_dict.items()):
    list_to_append = get_all_ItemProperties(item, Qid)
    related_pairs = np.vstack((related_pairs,list_to_append))
# Out:
# 100%|██████████| 6306/6306 [6:30:42<00:00,  3.72s/it]

# %%
# check how many of them do have properties

len(np.unique(related_pairs[:,0]))/len(pagetitle_qid_dict.keys())
# Out:
# 0.9628924833491912

# %% [markdown]
# # Filter properties

# %%
# the most frequent wikidata properties for our terms

unique_properties, counts_properties = np.unique(related_pairs[:,1], return_counts=True)

# %%
pd.set_option('max_row',1000)

property_df = pd.DataFrame(list(zip(unique_properties, counts_properties)),
                           columns =['property', 'count'])

property_df = property_df.sort_values(by=['count'], ascending=False)
property_df.head(100)
# Out:
#                                              property  count
# 242                                    found in taxon   8307
# 303                                       instance of   7095
# 523                                       subclass of   5538
# 195                           drug used for treatment   3114
# 412                                           part of   3062
# 167                               described by source   2500
# 269                                          has part   2453
# 353                         medical condition treated   2288
# 248                               genetic association   1925
# 70                                 biological process   1875
# 546                             topic's main category   1766
# 176                                    different from   1600
# 113                           child astronomical body   1584
# 524                                  subject has role   1431
# 280                                  health specialty   1096
# 525                                        subsidiary   1064
# 423                         physically interacts with   1008
# 490                      significant drug interaction    995
# 394                on focus list of Wikimedia project    883
# 407                                          owner of    872
# 37                               active ingredient in    723
# 145                                           country    520
# 134        contains administrative territorial entity    516
# 363                                molecular function    513
# 107                                    cell component    490
# 438                                pregnancy category    462
# 531                                          symptoms    462
# 568                                            winner    447
# 476                            said to be the same as    434
# 370                                       named after    423
# 219                                      expressed in    333
# 183                            discoverer or inventor    327
# 273                                       has quality    325
# 312                                     language used    315
# 311                          language of work or name    292
# 559                                               use    288
# 415                                       participant    286
# 547                             topic's main template    286
# 356                                         member of    262
# 279                             headquarters location    256
# 85                                        cast member    255
# 259                                         has cause    251
# 262                                        has effect    246
# 294                   indexed in bibliographic review    234
# 64                                     award received    227
# 244                                        founded by    222
# 178                               diplomatic relation    220
# 109                                       chairperson    220
# 521                                        studied by    218
# 337                                      main subject    194
# 400                                       opposite of    189
# 240                                           follows    185
# 147                                 country of origin    178
# 447                      product or material produced    176
# 323  located in the administrative territorial entity    170
# 491                                 significant event    161
# 239                                       followed by    160
# 458                              readable file format    152
# 44                                anatomical location    150
# 24                          LiverTox likelihood score    138
# 405                                          ortholog    138
# 455                                         publisher    137
# 475               safety classification and labelling    137
# 230                                     field of work    136
# 276                       has works in the collection    135
# 561                                              uses    134
# 222                                          facet of    134
# 165                                   derivative work    123
# 437                                      practiced by    123
# 354                              medical examinations    123
# 398                                  operating system    119
# 39                                        affiliation    115
# 295                                          industry    102
# 474                           route of administration    102
# 436                                possible treatment     99
# 406                                          owned by     98
# 450                              programming language     95
# 270                            has parts of the class     95
# 571                              writable file format     92
# 522                                           studies     92
# 171                                         developer     92
# 328                                          location     92
# 410                               parent organization     90
# 429                                          platform     89
# 468                                          replaces     89
# 487                                shares border with     87
# 360                                minor planet group     84
# 249                                             genre     83
# 261                        has edition or translation     79
# 285                                  history of topic     78
# 473                                       risk factor     77
# 493                    site of astronomical discovery     75
# 314                                        legal form     74
# 139                                 copyright license     74
# 40                                           afflicts     72
# 112                                             child     71
# 131                                     connects with     70
# 207                                        encoded by     68
# 379                                     nominated for     68
# 391                                 official language     68

# %%
# filter only the properties that are useful to us 
property_toremove = ['described by source',
                     'country',
                     'winner',
                     'owner of',
                     'contains administrative territorial entity',
                     'discoverer or inventor',
                     'language used',
                     'language of work or name',
                     'participant',
                     'headquarters location',
                     'indexed in bibliographic review',
                     'cast member',
                     'award received',
                     'founded by',
                     'chairperson',
                     'diplomatic relation',
                     'country of origin',
                     'located in the administrative territorial entity',
                     'LiverTox likelihood score',
                     'publisher',
                     'safety classification and labelling',
                     'has works in the collection',
                     'practiced by',
                     'medical examinations',
                     'operating system',
                     'affiliation',
                     'owned by',
                     'programming language',
                     'developer',
                     'developer',
                     'platform',
                     'shares border with',
                     'has edition or translation',
                     'history of topic',
                     'site of astronomical discovery',
                     'copyright license',
                     'afflicts',
                     'child',
                     'nominated for',
                     'official language'
                    ]

# %%
related_pairs_filtered = np.array([pair for pair in related_pairs 
                                   if pair[1] not in property_toremove 
                                   and pair[1] in property_df.property.values[:100].tolist()])

# %%
len(np.unique(related_pairs_filtered[:,0]))/len(pagetitle_qid_dict.keys())
# Out:
# 0.9606723755153822

# %%
np.savetxt('./wikidata_properties.txt', related_pairs, delimiter='\t', fmt='%s')
