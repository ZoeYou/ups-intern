# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#All-wikidata-properties" data-toc-modified-id="All-wikidata-properties-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>All wikidata properties</a></span></li><li><span><a href="#Get-wikidata-ID" data-toc-modified-id="Get-wikidata-ID-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Get wikidata ID</a></span></li><li><span><a href="#Get-properties" data-toc-modified-id="Get-properties-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Get properties</a></span></li><li><span><a href="#Filter-properties" data-toc-modified-id="Filter-properties-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Filter properties</a></span></li><li><span><a href="#How-do-they-connect-from-each-other?" data-toc-modified-id="How-do-they-connect-from-each-other?-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>How do they connect from each other?</a></span></li></ul></div>

# %% [markdown]
# # All wikidata properties

# %%
## wikidata property lookup table 

# pip install sparqlwrapper
# https://rdflib.github.io/sparqlwrapper/

import sys
from SPARQLWrapper import SPARQLWrapper, JSON

endpoint_url = "https://query.wikidata.org/sparql"

query = """#All properties with descriptions and aliases and types
SELECT ?property ?propertyTypeLabel ?propertyLabel ?propertyDescription ?propertyAltLabel WHERE {
  # ?property wikibase:propertyType ?propertyType.
  SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
  
}
ORDER BY (xsd:integer(STRAFTER(STR(?property), "P")))"""


def get_results(endpoint_url, query):
    user_agent = "WDQS-example Python/%s.%s" % (sys.version_info[0], sys.version_info[1])
    # TODO adjust user agent; see https://w.wiki/CX6
    sparql = SPARQLWrapper(endpoint_url, agent=user_agent)
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    return sparql.query().convert()

# %%
from pandas.io.json import json_normalize

results = get_results(endpoint_url, query)
all_wikidata_properties = json_normalize(results['results']['bindings'])

# get results 
all_wikidata_properties = all_wikidata_properties[['property.value',
                                                   'propertyTypeLabel.value',
                                                   'propertyLabel.value',
                                                   'propertyDescription.value',
                                                   'propertyAltLabel.value']]

all_wikidata_properties.columns = ['property_ID', 'DataType', 'property_name','description','examples']

# change formats
all_wikidata_properties['property_ID'] = all_wikidata_properties['property_ID'].str[31:]
all_wikidata_properties['DataType'] = all_wikidata_properties['DataType'][0][26:]

all_wikidata_properties.head()
# Out:
#   property_ID      DataType       property_name  \
# 0          P6  WikibaseItem  head of government
# 1         P10  WikibaseItem               video
# 2         P14  WikibaseItem        traffic sign
# 3         P15  WikibaseItem           route map
# 4         P16  WikibaseItem      highway system
#
#                                          description  \
# 0  head of the executive power of this town, city...
# 1  relevant video. For images, use the property P...
# 2  graphic symbol describing the item, used at th...
# 3            image of route map at Wikimedia Commons
# 4  system (or specific country specific road type...
#
#                                             examples
# 0  president, chancellor, mayor, prime minister, ...
# 1           animation, media, gif, trailer (Commons)
# 2  highway shield, shield, highway marker, motorw...
# 3  schema, highway map, map of route, metro map, ...
# 4  transport network, network of routes, part of ...

# %%
len(all_wikidata_properties)
# Out:
# 8823

# %% [markdown]
# So as we can see, wikidata has totally 8798 types of properties/relations.

# %% [markdown]
# # Get wikidata ID

# %%
TERM_LIST = '../01_make_matching_list/matching_list.csv'
WIKIDATA_DICT = './wikidata_id.csv'
WIKIDATA_PROPERTIES = './wikidata_properties.txt'

# %%
import pandas as pd 

matching_list = pd.read_csv(TERM_LIST,dtype={'wiki_title': str})

pagetitle_qid_dict = pd.read_csv(WIKIDATA_DICT, delimiter='\t', header=None, index_col=0).to_dict()[1]
matching_list['QID'] = matching_list['wiki_title'].map(pagetitle_qid_dict)

# %%
matching_list
# Out:
#                                    term annotation         df wiki_title  QID
# 0           aperture z-scan experiments    Process  scienceie        NaN  NaN
# 1       1560nm femtosecond laser pulses   Material  scienceie        NaN  NaN
# 2                       optical-chopper   Material  scienceie        NaN  NaN
# 3        vibrational combination states    Process  scienceie        NaN  NaN
# 4               non-radiative processes    Process  scienceie        NaN  NaN
# ...                                 ...        ...        ...        ...  ...
# 756416                 mmds hyper cable       TECH   wikidump        NaN  NaN
# 756417                   parley p pratt       TECH   wikidump        NaN  NaN
# 756418               de havilland pt-24       TECH   wikidump        NaN  NaN
# 756419        victorin-hippolyte jasset       TECH   wikidump        NaN  NaN
# 756420      blood-pledge corps incident       TECH   wikidump        NaN  NaN
#
# [756421 rows x 5 columns]

# %%
# target titles that we are going to find their QID
titles = matching_list[matching_list.wiki_title.notna() & matching_list.QID.isna()].wiki_title.values
titles
# Out:
# array(['Ω−ωf', 'Monoamine neurotransmitter', 'Monosodium glutamate', ...,
#        'Torsus Praetorian', 'Dictaphone', 'Subcontrabass flute'],
#       dtype=object)

# %%
len(titles)
# Out:
# 51350

# %%
import requests 
import urllib
import re 
from bs4 import BeautifulSoup

def get_wikidata_id(term):
    
    encoded_term = urllib.parse.quote(term)

    url = f"https://en.wikipedia.org/w/api.php?action=query&format=json&prop=pageprops&ppprop=wikibase_item&redirects=1&titles={encoded_term}"
    html = requests.get(url)
    soup = BeautifulSoup(html.text, 'html.parser').get_text()
    
    wikidata_id = re.findall('wikibase_item\"\:\"(.*)?\".*', soup)
    
    if wikidata_id != []:
        return wikidata_id[0]

# %%
# find wikidata ID for all terms
from tqdm import tqdm


not_found = []
for title in tqdm(titles):
    wikidata_id = get_wikidata_id(title)
    if wikidata_id:
        pagetitle_qid_dict.update({title: wikidata_id})
    else:
        not_found.append(title)
# Out:
# 100%|██████████| 51353/51353 [4:04:47<00:00,  3.50it/s]

# %%
not_found
# Out:
# ['Ω−ωf', 'Category:Streaming music services', 'Muscle fibres']

# %%
# remove the entities without wikidata ID
titles = [title for title in titles if title not in not_found]

# %%
# check disambiguation page
def is_disambiguation_page(wikidata_id):
    
    url = "https://www.wikidata.org/wiki/" + wikidata_id
    html = requests.get(url)
    soup = BeautifulSoup(html.text, 'html.parser')
    
    div = soup.find("div", {"class": "wikibase-entitytermsview-heading-description"}).text
    
    return div == 'Wikimedia disambiguation page'

# %%
QIDs = [pagetitle_qid_dict[title] for title in titles]

# %%
# check disambiguation page for list terms
to_remove = []

for title, wikidata_id in tqdm(zip(titles, QIDs)):
    if is_disambiguation_page(wikidata_id):
        to_remove.append(title)
# Out:
# 51350it [6:56:42,  2.05it/s]

# %%
to_remove
# Out:
# ['APAP',
#  'PAP',
#  'IDM',
#  'P11',
#  'Progestogen (medication)',
#  'Aza',
#  'Doca',
#  'SNP',
#  'TMP',
#  'Ciba',
#  'AVP',
#  'PHE',
#  'Pyrrolidone',
#  'OCS',
#  'NE',
#  'DEP',
#  'SCL',
#  'SIL',
#  'TR',
#  'LTR',
#  'DRA',
#  'U937',
#  'U1',
#  'GR',
#  'A10',
#  'Dorsal',
#  'Enhancer',
#  'Receptor',
#  'AP1',
#  'L1',
#  'L2',
#  'Pag',
#  'Promoter',
#  'Promoter',
#  'Oct',
#  'SP1',
#  'Tata',
#  'CSF',
#  'Jy',
#  'CRE',
#  'Transcript',
#  'Or',
#  'PR',
#  'Fos',
#  'Jun',
#  'TRE',
#  'Rex',
#  'Rex',
#  'Mnl',
#  'Lmp1',
#  'Daudi',
#  'Induction',
#  'C1',
#  '9S',
#  'ORF',
#  'RAC',
#  'P50',
#  'P105',
#  'Construct',
#  'Mab',
#  'P95',
#  'Seb',
#  'Jak',
#  'SP1',
#  'DCS',
#  'P65',
#  'Peer',
#  'IBR',
#  'EWG',
#  'Dimer',
#  'Factor',
#  'IL-9',
#  'D10',
#  'Bik',
#  'Bax',
#  'Bak',
#  'IL-3',
#  'Launch Complex 2',
#  'OCT1',
#  'Cofactor',
#  'Oct',
#  'Gata',
#  'M44',
#  'M67',
#  'Receptor',
#  'STAT',
#  'SFS',
#  'IL-10',
#  'E7',
#  'Silencer',
#  'ID',
#  'AGS',
#  'LCR',
#  'Zip',
#  'H5',
#  'Raz',
#  'YT',
#  'ILS',
#  'RAF (disambiguation)',
#  'Alpha subunit',
#  'EPO',
#  'IL-13',
#  'Gyre (disambiguation)',
#  'IL-5',
#  'Mek',
#  'Lyn',
#  'Rb',
#  'FAK',
#  'DARC',
#  'S6',
#  'B7',
#  'BPI',
#  'Cleo',
#  'MHC',
#  'DQ',
#  'X2',
#  'MCP1',
#  'G1',
#  'UPS',
#  'PRB',
#  'MBP',
#  'SSE',
#  'UTR',
#  'PAF',
#  'GRE (disambiguation)',
#  'Tat',
#  '2A',
#  '2B',
#  'Jak 2',
#  'P19',
#  'SP1',
#  'IG',
#  'Hela',
#  'Hel',
#  'H9',
#  'TRX',
#  'HBF',
#  'Effector',
#  'P84',
#  'P100',
#  'A1',
#  'A2',
#  'DPA',
#  'Tab',
#  'TTK',
#  'Ada',
#  'Oap',
#  'RAR',
#  'TF',
#  'T1',
#  'T2',
#  'B1',
#  'Max',
#  'U937',
#  'QR',
#  'M4',
#  'Nef',
#  'Chimera',
#  'Alpha 4',
#  'ERP',
#  'Cn',
#  'NFS',
#  'NF',
#  'II',
#  'P52',
#  'EA (disambiguation)',
#  'Tur',
#  'Zeb',
#  'HM',
#  'HB',
#  'GC',
#  'Lam',
#  'Par',
#  'Mac1',
#  'ECS',
#  'P57',
#  'P70',
#  'P72',
#  'Thr',
#  'LBR',
#  'TH1',
#  'LIF',
#  'AB',
#  'Gam',
#  'IGM',
#  'Rex',
#  'AP1',
#  'P49',
#  'Corticosteroid receptor',
#  'Type 1',
#  'Type 2',
#  'Mab',
#  'Promoter',
#  'Binding protein',
#  'IGD',
#  'H7',
#  'MS2',
#  'Erk',
#  'R24',
#  'Ko',
#  'ZP',
#  'M1',
#  'Mie',
#  'SNE',
#  'ETS',
#  'See',
#  'Raji',
#  'HF',
#  'Sig',
#  'TCC',
#  'Fadd',
#  'FDC',
#  'GC',
#  'P37',
#  'Fos',
#  'CTL',
#  'BTK',
#  'Rel',
#  'E47',
#  'E12',
#  'Yae',
#  'Gata',
#  'Ige',
#  'P55',
#  'CAK (disambiguation)',
#  'CRE',
#  'MYB',
#  'BCD',
#  'III',
#  'WP',
#  'TAF',
#  'HEB',
#  'RAF (disambiguation)',
#  'ETS',
#  'QP',
#  'P38',
#  'P63',
#  'P120',
#  'P15',
#  'P15',
#  'HGF',
#  'HSC',
#  'Pip',
#  'DHS (disambiguation)',
#  'A20',
#  'MUB',
#  'M32',
#  'M41',
#  'GST',
#  'Rareș',
#  'Rare',
#  'GRR',
#  'JH',
#  'TEC',
#  'P45',
#  'BCR',
#  'ABS',
#  'Gad',
#  'Ku',
#  'Pp1',
#  '17',
#  'XP',
#  'E1',
#  'PPS',
#  'Bad',
#  'CINC (disambiguation)',
#  'Nitric oxide synthetase',
#  'E1',
#  'T3',
#  'T4',
#  'CLS',
#  'P300',
#  'BM',
#  'P24',
#  'SHC',
#  'TEC',
#  'HSP',
#  'B29',
#  'BCS',
#  'MSR',
#  'GPX',
#  'P23',
#  'P48',
#  'IRF',
#  'Nef',
#  'Ikaros',
#  'Rip',
#  'Vav',
#  'D1',
#  'IGG',
#  'IL-10',
#  'M22',
#  'M47',
#  'S-adenosylhomocysteine hydrolase',
#  'A20',
#  'Ran',
#  'NPC',
#  'GF',
#  'GPA (disambiguation)',
#  'ECS',
#  'Adaptor protein',
#  'STP',
#  'PBM',
#  'Lat',
#  'Dp1',
#  'Mig',
#  'Delta',
#  'Mei',
#  'NOS',
#  'P40',
#  '50',
#  'P1',
#  'DCS',
#  'E47',
#  'P0',
#  'H19',
#  'SSB',
#  'IL-15',
#  'SP',
#  'NMI',
#  'Ki-67',
#  'D3',
#  'Trap',
#  'VR',
#  'C3a',
#  'PKB',
#  'P2',
#  'P3',
#  'P4',
#  'SP3',
#  'UBP',
#  'LER',
#  'SFV',
#  'CRH',
#  'LZ',
#  'FL',
#  'Taqi',
#  'Polymorphism',
#  'Eotaxin',
#  'PIF',
#  'Complex',
#  'HOX',
#  'POS',
#  'Toll',
#  'ESC',
#  'EED',
#  'PARP',
#  'Tap',
#  'Tip',
#  'SP-A',
#  'Ire',
#  'P85',
#  'Tat',
#  'U1',
#  'ABL',
#  'PBM',
#  'NE',
#  'SAF',
#  'HF',
#  'HM',
#  'Mediator',
#  'AMS',
#  'KB',
#  'TCC',
#  'A549',
#  'IK',
#  'P96',
#  'P54',
#  'Zap',
#  'Fab',
#  'Ge',
#  'HRF',
#  'Subunit',
#  'Tef',
#  'Skip',
#  'Ikaros',
#  'Precursor',
#  'Rank',
#  'Bash',
#  'Cos-1',
#  'C5a',
#  'LMO',
#  'LMO',
#  'RBP',
#  'OSM',
#  'HSI',
#  'FCR',
#  'KV',
#  'KCA',
#  'German submarine U-86',
#  'German submarine U-89',
#  'TH1',
#  'YJ',
#  'ECP',
#  'Xi',
#  'DARC',
#  'Pel',
#  'Delta',
#  'BP2',
#  'II',
#  'Hirak',
#  'DRA',
#  'CPO',
#  'PHK',
#  'Dp1',
#  'CALM',
#  'Q13',
#  'YAC',
#  'IL-18',
#  'Dil',
#  'Activator',
#  'IL-3',
#  'IL-5',
#  'Dorsal',
#  'IL-3',
#  'Red cell',
#  'TTP',
#  'PMA',
#  'Activator',
#  'LT',
#  'Z-gene',
#  'Pre',
#  'Receptor',
#  'Positive',
#  'Pol',
#  'Rev',
#  'M10',
#  'X1',
#  'Red cell',
#  'Locus',
#  'E74',
#  '9J',
#  'Complex',
#  'MU',
#  'Alas',
#  'B2',
#  'B3',
#  'E6',
#  'S1',
#  '82',
#  '67',
#  'B2',
#  'OTF',
#  'CTL',
#  'CBG',
#  'AML',
#  'MPS',
#  'Scavenger receptor',
#  'Rage',
#  'FCS',
#  'L2',
#  'SDF-1',
#  'HEB',
#  'E12',
#  'Cona',
#  'AML',
#  'ERC',
#  'Ern',
#  'PRN',
#  'C7',
#  'Subunit',
#  'REC',
#  'RPC',
#  'Vav',
#  'SRA',
#  'NP',
#  'Recombinase',
#  'Locus',
#  'ACAT',
#  'P7',
#  'P58',
#  'Bright',
#  'Bad',
#  'Max',
#  'Stam',
#  'Here',
#  'Flip',
#  'Nemo',
#  'Nemo',
#  'SAC',
#  'EGR',
#  'PLK',
#  'Alpha 6',
#  'Hop',
#  'Yi',
#  'Gal',
#  'TPB',
#  'Half dollar',
#  'USS Arkansas',
#  'Network 23',
#  'Black Pearl (disambiguation)',
#  'Change of Heart',
#  'A103',
#  'List of bitcoin forks',
#  'New Country',
#  'Military rule',
#  'Alfred Agache',
#  'Total pressure',
#  'Modern Times',
#  'Apple worm',
#  'Speech technology',
#  'Router table',
#  'State of Mind',
#  'Grand Central',
#  'U-70',
#  'Artisanal mining',
#  'Circuit rider',
#  'Lame duck',
#  'Variable-pitch propeller',
#  'Rolling Thunder',
#  'Stationary distribution',
#  'Red light',
#  'Farm Town',
#  'Queen Elizabeth',
#  'Stage wash',
#  'Free electron',
#  'Uranium oxide',
#  'Open system',
#  'Functional analog',
#  'Project X',
#  'Nova TV',
#  'HMS Furious',
#  'Round-robin',
#  "Bachelor's buttons",
#  'Vowel pointing',
#  "Faraday's law",
#  'Revolving door (disambiguation)',
#  'Resonant energy transfer',
#  'Reversibility',
#  'Hidden variable',
#  'Tint control',
#  'Peaches (disambiguation)',
#  'Dippy egg',
#  '↓',
#  'USS Tallahassee',
#  'A Clockwork Orange',
#  'Five-stroke method',
#  'Alpha strike',
#  'Sinus rectus',
#  'HMS Cressy',
#  'Do or Die',
#  'A Clockwork Orange',
#  'Ligaments of malleus',
#  'Asus Transformer',
#  'HMS Iron Duke',
#  'Joseph Newman',
#  "Cat's eye",
#  'HMS Caroline',
#  'David Vernon',
#  'Never summer',
#  'Internet company',
#  'Cross section',
#  'Pennsylvania Station (disambiguation)',
#  'Spaceship',
#  'Émeraude-class submarine',
#  'Time of flight',
#  'Tristis est anima mea',
#  'Glossary of military abbreviations',
#  'Lists of spacewalks and moonwalks',
#  'Night Stalker',
#  'Focal point',
#  'Media technology',
#  'Never Let You Go',
#  'Fior di latte',
#  'Gilt Edge',
#  'Pool-type reactor',
#  'Pedestrian tunnel',
#  "Dragon's Breath",
#  'Image space',
#  'Pirate Cove',
#  'Black Christmas',
#  'Yellow pine',
#  'Test subject',
#  'On location',
#  'Blue frog',
#  'Calling card',
#  'HMS Britannia',
#  'Austin Smith',
#  'Special Stage',
#  'Audio player',
#  'Compound meter',
#  'Pattern search',
#  'Rabbit hole',
#  'Presidential palace',
#  'List of Formula One records',
#  'Waterhole',
#  'Semantic anti-realism',
#  'Nearest neighbor',
#  'Matching',
#  'Progressive Party',
#  'Golden Arm (disambiguation)',
#  'Boyz n da Hood (disambiguation)',
#  'Lukewarm',
#  'Porte des Lilas',
#  'Silver Swan',
#  'Autumnal equinox',
#  "Wirtinger's inequality",
#  'Euler integral',
#  'White Line',
#  'Scottish referendum',
#  'Channel 6',
#  'Windowpane',
#  'Coastal defence',
#  'Interstate system',
#  'Polymeric foam',
#  'List of public transport routes numbered 15',
#  'Germanium fluoride',
#  'Ceres series',
#  'Havmanden-class submarine',
#  "Dragon's Tail",
#  "Clairaut's formula",
#  'Urban gardening',
#  'Tamil protests',
#  'Cruizer class',
#  'Chimerin',
#  'Firewater',
#  'Police surgeon',
#  'Army Staff',
#  'Black gold',
#  'White book',
#  'Like a Virgin',
#  'Point of view',
#  'Black Stream',
#  'Drum Tower',
#  'Severe weather terminology',
#  'Time reversibility',
#  'HMS Arrow',
#  'Peter Whittle',
#  'Autumnal equinox',
#  'Offshore structure',
#  'Conductor rail',
#  'Economics of extraterrestrial resource extraction',
#  'Cover',
#  'Hilbert basis',
#  'John Smith',
#  'History of electricity',
#  'USS Virginia',
#  'Whiteout',
#  'Bank of America Plaza',
#  'Baby Doll (disambiguation)',
#  'Highflyer',
#  'USS California',
#  'Mirrors and forks',
#  'HMS Bristol',
#  'First impression',
#  'Live birth',
#  'Saint Philip',
#  'Encrypted filesystem',
#  'Evening Star',
#  'Smart terminal',
#  'Floating lantern',
#  'Community channel',
#  'Power suit',
#  'Live performance',
#  'Mobile warfare',
#  'USS Randolph',
#  'Growth model',
#  'Hidden variable',
#  'Michael Collins',
#  'Hose strap',
#  'Reproductive value',
#  'Interstate 195',
#  'Wheel stops',
#  'Magnetic braking',
#  'Surgeon general',
#  'Night Watch',
#  'Bonding electron',
#  'True Colors',
#  'John Brown',
#  'French ship Gloire',
#  'Orbital angular momentum',
#  'Vedic timeline',
#  'Game addiction',
#  'William of Orange',
#  'Coors 200',
#  'Silver Lining',
#  'Arthur Hull',
#  'Yellow Cross',
#  'Implication',
#  'Electronic watch',
#  'China Syndrome',
#  'Doctor Zhivago',
#  'Coupling coefficient',
#  'Audio effect',
#  'Interstate 280',
#  'German submarine U-53',
#  'Yellow Submarine',
#  'Supply chain finance',
#  'Salver',
#  'Infernal machine',
#  'Complexity measure',
#  'Years of Lead',
#  'Biological clock',
#  'Powder Magazine',
#  'Silent partner',
#  'Chinook helicopter crash',
#  'HMS Sappho',
#  'Separate reality',
#  'Power structure',
#  'German submarine U-103',
#  "Fermat's theorem",
#  'Spring flowers',
#  'White box',
#  'Broken Arrow',
#  'Closed loop',
#  'Fundamental physical constant',
#  'Intermodal car',
#  'Altitude record',
#  'Parallel universe',
#  'Strawberries and cream',
#  'Time brokerage agreement',
#  'Hare and Hounds',
#  'HMS Warwick',
#  'Floating city',
#  'Alien visitation',
#  'Law of attraction',
#  'Manganese oxide',
#  'Cup and saucer',
#  'HMS Royal Sovereign',
#  'Northern Lights',
#  'Constitution type',
#  'Trust management',
#  'Autumnal equinox',
#  'USS Barracuda',
#  'Open College',
#  'All for You',
#  'Oil recovery',
#  "Child's Play",
#  'Safe area',
#  'Königsberg-class cruiser',
#  'R-class destroyer',
#  'Black Belt',
#  'Screen',
#  'National Diploma',
#  'Media room',
#  'Information filter',
#  'Azadi march',
#  'Live and Let Die',
#  'Majolica',
#  'Boring machine',
#  'Control point',
#  'Festival of Lights',
#  "Schrödinger's paradox",
#  'Dark Ages',
#  'Electron Pair Production',
#  'Cone of Silence',
#  'Moori',
#  'Summit Station',
#  'Fort-class replenishment ship',
#  "Jockey's cap",
#  'List of public transport routes numbered 8',
#  'Collaborative economy',
#  'Coffin corner',
#  'Parachute Regiment',
#  'Relict',
#  'Protection policy',
#  'Hash tree',
#  'Heaven and Earth',
#  'Dark Water',
#  'German submarine U-137',
#  'E3 series',
#  'State farm',
#  'Up and Down',
#  'Boiler room',
#  'Kaiser effect',
#  'System32',
#  'Idiot box',
#  'Arethusa-class cruiser',
#  'Direct method',
#  'Match point',
#  'Firing Line',
#  'The Dogs of War',
#  'Castle Thunder',
#  'HMS Delhi',
#  'Defence Forces',
#  'Sampling',
#  'Channel 8',
#  'Hilary Rose',
#  'Midnight Express',
#  'Yellow Book',
#  'Critical path',
#  'HMS Brilliant',
#  'Wohl model',
#  'Farragut-class destroyer',
#  'Musical performance',
#  'Golden number',
#  'Channel 40',
#  'Mesenteric arteries',
#  'Direct conversion',
#  'Miller 200',
#  'Stretch receptor',
#  'Fire resistance',
#  'Flight 7',
#  'Carver matrix',
#  'Committee of 100',
#  'Interossei',
#  'Force of nature',
#  'Woodchip',
#  'Unfinished Portrait',
#  'White space',
#  'Solar storm',
#  'Up All Night',
#  'San Pedro',
#  'Dark blue',
#  'Science (disambiguation)',
#  'Water jet',
#  'Super Heavy',
#  'Human chain',
#  'Double Cross',
#  'Strawberry tree',
#  'Grandmaster',
#  'Waterwitch',
#  'Game character',
#  'Count On Me',
#  'Cursive script',
#  'Prom Night',
#  'Police helmet',
#  'Power-to-weight ratio',
#  'Specific fuel consumption',
#  'Surface temperature',
#  'USS Alexandria',
#  'State vector',
#  'Nokia 6500',
#  "Shepherd's hook",
#  'Channel 3',
#  'Basilar part',
#  'HTTP authentication',
#  'USS Archerfish',
#  'Time binding',
#  'HMS Newcastle',
#  'German submarine U-135',
#  'Umbrella Man',
#  'Crazy for You',
#  'List of public transport routes numbered 18',
#  'Uniflow engine',
#  'Environmental reporting',
#  'Channel 35',
#  'Different World',
#  'Revisionist history',
#  'Chinook helicopter crash',
#  'Shoulder surfing',
#  'Saleem Ali',
#  'Truther',
#  'Wells score',
#  'GM Ecotec engine',
#  'A-class destroyer',
#  'HMS Gannet',
#  'Level of service',
#  'War college',
#  'HMS Royal George',
#  'List of amino acids',
#  'Alarmism',
#  'Channel 19',
#  'Curvature tensor',
#  'Coast to Coast',
#  'Lightning bolt',
#  'Einstein relation',
#  'Grand cru',
#  'Republican guard',
#  'Day of reckoning',
#  'Soul rock',
#  'City Lights (disambiguation)',
#  'Mars 2018 mission',
#  'Silent alarm',
#  'Glass house',
#  'Channel 14',
#  'Black cross',
#  'Rigidity theory',
#  'HMS Ark Royal',
#  'Breaking Point',
#  'Academy of Information Technology',
#  'Food pyramid',
#  'Solar probe',
#  'I seek you',
#  'Signed Sealed Delivered',
#  'Symplectic space',
#  'Sweet spot',
#  'Flying frog',
#  'Backhaul',
#  'Sulcus terminalis',
#  'Mars mission',
#  'Inversion layer',
#  'Stars and bars',
#  'Plutonium fluoride',
#  'Channel 26',
#  "St. Andrew's Cross",
#  'Submarine cable',
#  'City of Angels',
#  'South Pacific',
#  'Autonomous system',
#  'Playing God',
#  'Magnetic trap',
#  'USS Georgia',
#  'Electrochemical fluorination',
#  'HMS Upholder',
#  'Pilot season',
#  'Insect mouthparts',
#  'Critical line',
#  'Channel 13',
#  'Contact',
#  'Wave mechanics',
#  'List of highways numbered 180',
#  'Pressure wave',
#  'Channel 16',
#  'Computer club',
#  'Boy howdy',
#  'Atomic energy',
#  'Ghost soldier',
#  'Celtic warrior',
#  'Job control',
#  'Xenon lamp',
#  'Joule effect',
#  'Almost Human',
#  'Family Portrait',
#  'Ministry of Petroleum',
#  'Real rank',
#  'Road locomotive',
#  'Energy efficiency',
#  'HMS Pique',
#  'USS Bristol',
#  'Scalar',
#  'Case management',
#  'British Bulldog',
#  'Photo editor',
#  'High dynamic range (disambiguation)',
#  'Adult-oriented rock',
#  'Mock orange',
#  'Node module',
#  'Discovery system',
#  'HMS Sheffield',
#  'Deutschland incident',
#  'Wandering eye',
#  'Discount rate',
#  'Grand Alliance',
#  'Nashville 200',
#  'Ormen Lange',
#  'Office space',
#  'List of A15 roads',
#  'Married Life',
#  'Third Age (disambiguation)',
#  'Mini football',
#  'Bishop Ring',
#  'Software implementation',
#  'Hospital emergency codes',
#  'New music',
#  'Torsion field',
#  'Channel 5',
#  'Fire detection',
#  'When We Were Young',
#  'HMS Revenge',
#  'Green Line',
#  'HMS Camperdown',
#  'Crash course',
#  'HMS Endurance',
#  'Gold Line',
#  'Book of Days',
#  'Heavy metal',
#  'Bathurst riots',
#  'Königsberg-class cruiser',
#  'Configuration space',
#  'Translink',
#  'Channel 67',
#  'IPhone SE',
#  'Atomic lattice',
#  'Six Mile Lake',
#  'Test track',
#  'Double cover',
#  'Alley cat',
#  'Channel 50',
#  'Proximity effect',
#  'Frost damage',
#  'Plasma cannon',
#  'Calling card',
#  'Microchip implant',
#  'Lifeline',
#  'Fireball',
#  'Power-to-weight ratio',
#  'Green Cross',
#  'I with diaeresis',
#  'Uniform distribution',
#  'Site exploitation',
#  'Belle de Jour',
#  'Relocker',
#  'List of national railway administrations',
#  'HMS Monarch',
#  'E1 series',
#  'White spruce',
#  'Transport theory',
#  'Walleye epidermal hyperplasia virus',
#  'Redshirt',
#  'Margin of safety',
#  'Passivation',
#  'A Star Is Born',
#  'Country song',
#  'Electric universe',
#  '5-inch gun',
#  'Goddess of Liberty',
#  'Do not disturb',
#  'Field theory',
#  'Earth return',
#  ...]

# %%
len(to_remove)/len(titles)
# Out:
# 0.0197078870496592

# %%
# # remove disambiguation page from list entities
# for key in to_remove:
#     dict_pagetitle_qid.pop(key)

# %%
pd.DataFrame([(k,v) for k,v in pagetitle_qid_dict.items()]).to_csv(WIKIDATA_DICT, header=None, index=False, sep='\t')

# %% [markdown]
# # Get properties

# %%
import numpy as np

def retrieve_value_P(P):
    for i in range(len(all_wikidata_properties)):
        if P == all_wikidata_properties['property_ID'][i]:
            return all_wikidata_properties['property_name'][i]


def retrieve_value_Q(Q):    
    url = f"https://www.wikidata.org/w/api.php?action=wbgetentities&format=json&props=labels&languages=en&ids={Q}"
    json_response = requests.get(url).json()
    entities = json_response.get('entities')
    
    entity = entities.get(Q)
    if entity:
        labels = entity.get('labels')
        if labels:
            en = labels.get('en')
            if en:
                value = en.get('value')
                return value 


def get_all_ItemProperties(wikidata_item, wikidata_id):
    url = "https://www.wikidata.org/w/api.php?action=wbgetclaims&format=json&entity="+wikidata_id
    json_response = requests.get(url).json()

    properties = [*json_response.get('claims').values()]
    
    res = np.empty(shape=[0, 3])
    
    for p in properties:   
        for d in p: 
            dict_ = d['mainsnak']
        
            # ignore if not a wikibase item
            if dict_['datatype'] != 'wikibase-item' or dict_['snaktype'] != 'value':
                continue 
                
            # replace all the wikidataItem ID by wikidataItem name          
            property_value = retrieve_value_Q(dict_['datavalue']['value']['id'])
            
            if property_value is None:
                continue
            
            # find property value in the previous lookup table
            property_ = retrieve_value_P(dict_['property'])
            
            row_to_append = [wikidata_item, property_, property_value]
  
            res = np.append(res, [row_to_append], 0)  
  
    return res

# %%
## example
# get_all_ItemProperties(wikidata_item='algorithm', wikidata_id='Q8366')

# %%
# find related pairs for all items in our dictionary
if WIKIDATA_PROPERTIES:
    related_pairs = np.loadtxt('./wikidata_properties.txt', delimiter='\t', dtype='str')
else:
    related_pairs = np.empty(shape=[0, 3])

# %%
for item, Qid in tqdm(pagetitle_qid_dict.items()):
    if item not in related_pairs[:,0]:
        
        list_to_append = get_all_ItemProperties(item, Qid)
        related_pairs = np.vstack((related_pairs,list_to_append))
# Out:
# 100%|██████████| 43943/43943 [11:48:53<00:00,  1.03it/s]

# %%
# check how many of them do have properties

len(np.unique(related_pairs[:,0]))/len(pagetitle_qid_dict.keys())
# Out:
# 0.8052477072571286

# %%
# save all of them
np.savetxt(WIKIDATA_PROPERTIES, related_pairs, delimiter='\t', fmt='%s')

# %% [markdown]
# # Filter properties

# %%
# the most frequent wikidata properties for our terms
unique_properties, counts_properties = np.unique(related_pairs[:,1], return_counts=True)

# %%
pd.set_option('max_row',1000)

property_df = pd.DataFrame(list(zip(unique_properties, counts_properties)),
                           columns =['property', 'count'])

property_df = property_df.sort_values(by=['count'], ascending=False)
property_df.head(100)
# Out:
#                                              property  count
# 449                                       instance of  28572
# 799                                       subclass of  28122
# 353                                    found in taxon  12257
# 397                                          has part   9012
# 834                             topic's main category   8902
# 251                               described by source   8763
# 619                                           part of   7462
# 116                                biological process   7120
# 262                                    different from   5450
# 287                           drug used for treatment   3400
# 214                                           country   2960
# 534                         medical condition treated   2472
# 564                                       named after   2436
# 552                                molecular function   2363
# 857                                               use   2291
# 365                               genetic association   2270
# 161                                    cell component   2264
# 583                                        occupation   2025
# 321                                      expressed in   1930
# 801                                  subject has role   1843
# 596                on focus list of Wikimedia project   1748
# 107                                    award received   1740
# 325                                          facet of   1730
# 171                           child astronomical body   1633
# 802                                        subsidiary   1578
# 412                                  health specialty   1534
# 614                                          owner of   1437
# 217                                 country of origin   1335
# 636                         physically interacts with   1329
# 538                                         member of   1193
# 271                            discoverer or inventor   1158
# 524                                      manufacturer   1110
# 841                                         tributary   1081
# 721                            said to be the same as   1077
# 402                                       has quality   1074
# 601                                          operator   1042
# 748                      significant drug interaction   1035
# 835                             topic's main template   1021
# 812                                          symptoms   1019
# 350                                           follows    977
# 860                                              uses    975
# 349                                       followed by    970
# 136                                       cast member    965
# 612                                          ortholog    917
# 497  located in the administrative territorial entity    889
# 366                                             genre    888
# 602                                       opposite of    866
# 645                                          platform    837
# 512                                made from material    815
# 473                          language of work or name    799
# 59                               active ingredient in    793
# 411                             headquarters location    780
# 797                                        studied by    767
# 167                                        characters    767
# 199        contains administrative territorial entity    733
# 618                                      parent taxon    721
# 817                                        taxon rank    700
# 749                                 significant event    692
# 671                      product or material produced    677
# 295                                       educated at    672
# 659                                      practiced by    633
# 257                                         developer    626
# 385                                        has effect    619
# 279                                  doctoral student    618
# 502                                          location    612
# 337                                     field of work    605
# 881                                            winner    604
# 382                                         has cause    567
# 369                                        given name    565
# 216                            country of citizenship    538
# 517                                      main subject    529
# 462                                      is a list of    527
# 600                                  operating system    522
# 740                                     sex or gender    521
# 660                                pregnancy category    521
# 578                                      notable work    519
# 398                            has parts of the class    500
# 355                                        founded by    499
# 622                                       participant    490
# 858                                           used by    479
# 690                              readable file format    462
# 300                                          employer    449
# 475                                     language used    441
# 613                                          owned by    423
# 637                                    place of birth    422
# 439                                          industry    417
# 249                                   derivative work    405
# 476               languages spoken, written or signed    404
# 264                               diplomatic relation    398
# 442                                     influenced by    391
# 305                                           encodes    386
# 406                       has works in the collection    379
# 189                                          conflict    372
# 684                                         publisher    362
# 769                                             sport    358
# 170                                             child    352
# 328                                       family name    350
# 127                                   calculated from    324
# 384                        has edition or translation    311
# 222                                           creator    309

# %%
# filter only the properties that are useful to us 
property_toremove = ['described by source',
                     'country',
                     'winner',
                     'owner of',
                     'contains administrative territorial entity',
                     'discoverer or inventor',
                     'language used',
                     'language of work or name',
                     'participant',
                     'headquarters location',
                     'indexed in bibliographic review',
                     'cast member',
                     'award received',
                     'founded by',
                     'chairperson',
                     'diplomatic relation',
                     'country of origin',
                     'located in the administrative territorial entity',
                     'LiverTox likelihood score',
                     'publisher',
                     'safety classification and labelling',
                     'has works in the collection',
                     'practiced by',
                     'medical examinations',
                     'operating system',
                     'affiliation',
                     'owned by',
                     'programming language',
                     'developer',
                     'platform',
                     'shares border with',
                     'has edition or translation',
                     'history of topic',
                     'site of astronomical discovery',
                     'copyright license',
                     'afflicts',
                     'child',
                     'nominated for',
                     'official language',
                     'occupation',
                     'on focus list of Wikimedia project',
                     "topic's main template",
                     'characters',
                     'educated at',
                     'doctoral student',
                     'given name',
                     'country of citizenship',
                     'is a list of',
                     'pregnancy category',
                     'notable work',
                     'place of birth',
                     'languages spoken, written or signed',
                     'influenced by',
                     'sport',
                     'family name',
                     'creator'
                    ]

# %%
related_pairs_filtered = np.array([pair for pair in related_pairs 
                                   if pair[1] not in property_toremove 
                                   and pair[1] in property_df.property.values[:100].tolist()])

# %%
len(np.unique(related_pairs_filtered[:,0]))/len(pagetitle_qid_dict.keys())
# Out:
# 0.7956671142161437

# %% [markdown]
# # How do they connect from each other?

# %%
# knowledge graph visualization
