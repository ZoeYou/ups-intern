# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#All-wikidata-properties" data-toc-modified-id="All-wikidata-properties-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>All wikidata properties</a></span></li><li><span><a href="#Filter-properties" data-toc-modified-id="Filter-properties-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Filter properties</a></span></li><li><span><a href="#Get-wikidata-ID" data-toc-modified-id="Get-wikidata-ID-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Get wikidata ID</a></span></li><li><span><a href="#Get-properties" data-toc-modified-id="Get-properties-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Get properties</a></span></li></ul></div>

# %% [markdown]
# # All wikidata properties

# %%
## wikidata property lookup table 

# pip install sparqlwrapper
# https://rdflib.github.io/sparqlwrapper/

import sys
from SPARQLWrapper import SPARQLWrapper, JSON

endpoint_url = "https://query.wikidata.org/sparql"

query = """#All properties with descriptions and aliases and types
SELECT ?property ?propertyTypeLabel ?propertyLabel ?propertyDescription ?propertyAltLabel WHERE {
  # ?property wikibase:propertyType ?propertyType.
  SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
  
}
ORDER BY (xsd:integer(STRAFTER(STR(?property), "P")))"""


def get_results(endpoint_url, query):
    user_agent = "WDQS-example Python/%s.%s" % (sys.version_info[0], sys.version_info[1])
    # TODO adjust user agent; see https://w.wiki/CX6
    sparql = SPARQLWrapper(endpoint_url, agent=user_agent)
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    return sparql.query().convert()

# %%
from pandas.io.json import json_normalize

results = get_results(endpoint_url, query)
all_wikidata_properties = json_normalize(results['results']['bindings'])

# get results 
all_wikidata_properties = all_wikidata_properties[['property.value',
                                                   'propertyTypeLabel.value',
                                                   'propertyLabel.value',
                                                   'propertyDescription.value',
                                                   'propertyAltLabel.value']]

all_wikidata_properties.columns = ['property_ID', 'DataType', 'property_name','description','examples']

# change formats
all_wikidata_properties['property_ID'] = all_wikidata_properties['property_ID'].str[31:]
all_wikidata_properties['DataType'] = all_wikidata_properties['DataType'][0][26:]

all_wikidata_properties.head()
# Out:
#   property_ID      DataType       property_name  \
# 0          P6  WikibaseItem  head of government
# 1         P10  WikibaseItem               video
# 2         P14  WikibaseItem        traffic sign
# 3         P15  WikibaseItem           route map
# 4         P16  WikibaseItem      highway system
#
#                                          description  \
# 0  head of the executive power of this town, city...
# 1  relevant video. For images, use the property P...
# 2  graphic symbol describing the item, used at th...
# 3            image of route map at Wikimedia Commons
# 4  system (or specific country specific road type...
#
#                                             examples
# 0  president, chancellor, mayor, prime minister, ...
# 1           animation, media, gif, trailer (Commons)
# 2  highway shield, shield, highway marker, motorw...
# 3  schema, highway map, map of route, metro map, ...
# 4  transport network, network of routes, part of ...

# %%
len(all_wikidata_properties)
# Out:
# 8799

# %% [markdown]
# So as we can see, wikidata has totally 8798 types of properties/relations.

# %% [markdown]
# # Filter properties

# %% [markdown]
# There are too many perperties, but we are going to only keep those whose datatype is WikibaseItem, and also the properties that are useful for us to find the hyponyms, hypernyms, synonyms etc.
#
# https://www.wikidata.org/wiki/Wikidata:Database_reports/List_of_properties/Top100

# %%
top100 = ['cites work',
        'series ordinal',
        'author name string',
        'instance of',
        'stated in',
        'retrieved',
        'PubMed ID',
        'reference URL',
        'publication date',
        'title',
        'published in',
        'page(s)',
        'volume',
        'apparent magnitude',
        'astronomical filter',
        'issue',
        'catalog code',
        'DOI',
        'catalog',
        'author',
        'language of work or name',
        'main subject',
        'country',
        'PMCID',
        'of',
        'located in the administrative territorial entity',
        'proper motion',
        'point in time',
        'determination method',
        'stated as',
        'coordinate location',
        'occupation',
        'SIMBAD ID',
        'right ascension',
        'declination',
        'epoch',
        'found in taxon',
        'sex or gender',
        'constellation',
        'start time',
        'Google Knowledge Graph ID',
        'VIAF ID',
        'given name',
        'parallax',
        'date of birth',
        'ortholog',
        'Wikimedia import URL',
        'radial velocity',
        'ResearchGate publication ID',
        'Freebase ID',
        'imported from Wikimedia project',
        'country of citizenship',
        'named as',
        'part of',
        'image',
        'GeoNames ID',
        'end time',
        'distance from Earth',
        'based on heuristic',
        'chromosome',
        'exact match',
        'family name',
        'Commons category',
        'subclass of',
        'Entrez Gene ID',
        'parent taxon',
        'taxon rank',
        'taxon name',
        'GNS Unique Feature ID',
        'place of birth',
        'Elo rating',
        'collection',
        'described by source',
        'date of death',
        'UniProt protein ID',
        'inception',
        'ORCID iD',
        'GBIF taxon ID',
        'location',
        'educated at',
        'category combines topics',
        'applies to jurisdiction',
        'languages spoken, written or signed',
        'heritage designation',
        'located in time zone',
        'GND ID',
        'postal code',
        'WorldCat Identities ID',
        'sport',
        'follows',
        'followed by',
        'has part',
        'population',
        'The Peerage person ID',
        'curator',
        'Dimensions Publication ID',
        'member of sports team',
        'employer',
        'genomic assembly',
        'official name']

# %%
len(top100)
# Out:
# 100

# %%
import pandas as pd 
pd.set_option('max_row',1000)


useful_properties = all_wikidata_properties[all_wikidata_properties.property_name.isin(top100)]
useful_properties = useful_properties[useful_properties.DataType == 'WikibaseItem']

useful_properties
# Out:
#      property_ID      DataType  \
# 5            P17  WikibaseItem
# 6            P18  WikibaseItem
# 7            P19  WikibaseItem
# 9            P21  WikibaseItem
# 13           P27  WikibaseItem
# 15           P31  WikibaseItem
# 24           P50  WikibaseItem
# 27           P54  WikibaseItem
# 30           P59  WikibaseItem
# 34           P69  WikibaseItem
# 50          P105  WikibaseItem
# 51          P106  WikibaseItem
# 52          P108  WikibaseItem
# 70          P131  WikibaseItem
# 77          P143  WikibaseItem
# 82          P155  WikibaseItem
# 83          P156  WikibaseItem
# 94          P171  WikibaseItem
# 111         P195  WikibaseItem
# 125         P214  WikibaseItem
# 133         P225  WikibaseItem
# 134         P227  WikibaseItem
# 154         P248  WikibaseItem
# 166         P276  WikibaseItem
# 169         P279  WikibaseItem
# 170         P281  WikibaseItem
# 183         P304  WikibaseItem
# 192         P351  WikibaseItem
# 193         P352  WikibaseItem
# 197         P356  WikibaseItem
# 201         P361  WikibaseItem
# 209         P373  WikibaseItem
# 229         P407  WikibaseItem
# 241         P421  WikibaseItem
# 250         P433  WikibaseItem
# 270         P459  WikibaseItem
# 286         P478  WikibaseItem
# 303         P496  WikibaseItem
# 329         P527  WikibaseItem
# 330         P528  WikibaseItem
# 368         P569  WikibaseItem
# 369         P570  WikibaseItem
# 370         P571  WikibaseItem
# 374         P577  WikibaseItem
# 377         P580  WikibaseItem
# 378         P582  WikibaseItem
# 379         P585  WikibaseItem
# 411         P625  WikibaseItem
# 427         P641  WikibaseItem
# 428         P642  WikibaseItem
# 431         P646  WikibaseItem
# 444         P659  WikibaseItem
# 468         P684  WikibaseItem
# 482         P698  WikibaseItem
# 487         P703  WikibaseItem
# 515         P734  WikibaseItem
# 516         P735  WikibaseItem
# 583         P813  WikibaseItem
# 616         P846  WikibaseItem
# 622         P854  WikibaseItem
# 651         P887  WikibaseItem
# 676         P921  WikibaseItem
# 687         P932  WikibaseItem
# 720         P971  WikibaseItem
# 721         P972  WikibaseItem
# 739        P1001  WikibaseItem
# 792        P1057  WikibaseItem
# 814        P1082  WikibaseItem
# 819        P1087  WikibaseItem
# 921        P1215  WikibaseItem
# 929        P1227  WikibaseItem
# 1038       P1343  WikibaseItem
# 1102       P1412  WikibaseItem
# 1120       P1433  WikibaseItem
# 1122       P1435  WikibaseItem
# 1135       P1448  WikibaseItem
# 1161       P1476  WikibaseItem
# 1184       P1545  WikibaseItem
# 1205       P1566  WikibaseItem
# 1272       P1640  WikibaseItem
# 1412       P1810  WikibaseItem
# 1516       P1932  WikibaseItem
# 1665       P2093  WikibaseItem
# 1781       P2214  WikibaseItem
# 1782       P2215  WikibaseItem
# 1783       P2216  WikibaseItem
# 1881       P2326  WikibaseItem
# 2125       P2583  WikibaseItem
# 2203       P2671  WikibaseItem
# 2380       P2860  WikibaseItem
# 2407       P2888  WikibaseItem
# 2584       P3083  WikibaseItem
# 4091       P4638  WikibaseItem
# 4108       P4656  WikibaseItem
# 5261       P5875  WikibaseItem
# 5552       P6179  WikibaseItem
# 5627       P6257  WikibaseItem
# 5628       P6258  WikibaseItem
# 5629       P6259  WikibaseItem
# 7164       P7859  WikibaseItem
#
#                                          property_name  \
# 5                                              country
# 6                                                image
# 7                                       place of birth
# 9                                        sex or gender
# 13                              country of citizenship
# 15                                         instance of
# 24                                              author
# 27                               member of sports team
# 30                                       constellation
# 34                                         educated at
# 50                                          taxon rank
# 51                                          occupation
# 52                                            employer
# 70    located in the administrative territorial entity
# 77                     imported from Wikimedia project
# 82                                             follows
# 83                                         followed by
# 94                                        parent taxon
# 111                                         collection
# 125                                            VIAF ID
# 133                                         taxon name
# 134                                             GND ID
# 154                                          stated in
# 166                                           location
# 169                                        subclass of
# 170                                        postal code
# 183                                            page(s)
# 192                                     Entrez Gene ID
# 193                                 UniProt protein ID
# 197                                                DOI
# 201                                            part of
# 209                                   Commons category
# 229                           language of work or name
# 241                               located in time zone
# 250                                              issue
# 270                               determination method
# 286                                             volume
# 303                                           ORCID iD
# 329                                           has part
# 330                                       catalog code
# 368                                      date of birth
# 369                                      date of death
# 370                                          inception
# 374                                   publication date
# 377                                         start time
# 378                                           end time
# 379                                      point in time
# 411                                coordinate location
# 427                                              sport
# 428                                                 of
# 431                                        Freebase ID
# 444                                   genomic assembly
# 468                                           ortholog
# 482                                          PubMed ID
# 487                                     found in taxon
# 515                                        family name
# 516                                         given name
# 583                                          retrieved
# 616                                      GBIF taxon ID
# 622                                      reference URL
# 651                                 based on heuristic
# 676                                       main subject
# 687                                              PMCID
# 720                           category combines topics
# 721                                            catalog
# 739                            applies to jurisdiction
# 792                                         chromosome
# 814                                         population
# 819                                         Elo rating
# 921                                 apparent magnitude
# 929                                astronomical filter
# 1038                               described by source
# 1102               languages spoken, written or signed
# 1120                                      published in
# 1122                              heritage designation
# 1135                                     official name
# 1161                                             title
# 1184                                    series ordinal
# 1205                                       GeoNames ID
# 1272                                           curator
# 1412                                          named as
# 1516                                         stated as
# 1665                                author name string
# 1781                                          parallax
# 1782                                     proper motion
# 1783                                   radial velocity
# 1881                             GNS Unique Feature ID
# 2125                               distance from Earth
# 2203                         Google Knowledge Graph ID
# 2380                                        cites work
# 2407                                       exact match
# 2584                                         SIMBAD ID
# 4091                             The Peerage person ID
# 4108                              Wikimedia import URL
# 5261                       ResearchGate publication ID
# 5552                         Dimensions Publication ID
# 5627                                   right ascension
# 5628                                       declination
# 5629                                             epoch
# 7164                            WorldCat Identities ID
#
#                                             description  \
# 5     sovereign state of this item (not to be used f...
# 6     image of relevant illustration of the subject;...
# 7     most specific known (e.g. city instead of coun...
# 9     sex or gender identity of human or animal. For...
# 13    the object is a country that recognizes the su...
# 15    that class of which this subject is a particul...
# 24    main creator(s) of a written work (use on work...
# 27    sports teams or clubs that the subject current...
# 30    the area of the celestial sphere of which the ...
# 34          educational institution attended by subject
# 50                       level in a taxonomic hierarchy
# 51    occupation of a person; see also "field of wor...
# 52    person or organization for which the subject w...
# 70    the item is located on the territory of the fo...
# 77    source of this claim's value; used in referenc...
# 82    immediately prior item in a series of which th...
# 83    immediately following item in a series of whic...
# 94        closest parent taxon of the taxon in question
# 111   art, museum, archival, or bibliographic collec...
# 125   identifier for the Virtual International Autho...
# 133   correct scientific name of a taxon (according ...
# 134   identifier from an international authority fil...
# 154   to be used in the references field to refer to...
# 166   location of the object, structure or event. In...
# 169   next higher class or type; all instances of th...
# 170   identifier assigned by postal authorities for ...
# 183      page number of source referenced for statement
# 192   identifier for a gene per the NCBI Entrez data...
# 193   identifier for a protein per the UniProt datab...
# 197   serial code used to uniquely identify digital ...
# 201   object of which the subject is a part (if this...
# 209   name of the Wikimedia Commons category contain...
# 229   language associated with this creative work (s...
# 241                             time zone for this item
# 250   issue of a newspaper, a scientific journal or ...
# 270   how a value is determined, or the standard by ...
# 286   volume of a book or music release in a collect...
# 303                             identifier for a person
# 329   part of this subject; inverse property of "par...
# 330   catalog name of an object, use with qualifier ...
# 368                  date on which the subject was born
# 369                      date on which the subject died
# 370   date or point in time when the subject came in...
# 374   date or point in time when a work was first pu...
# 377   time an item begins to exist or a statement st...
# 378   time an item ceases to exist or a statement st...
# 379   time and date something took place, existed or...
# 411   geocoordinates of the subject. For Earth, plea...
# 427   sport that the subject participates or partici...
# 428   qualifier stating that a statement applies wit...
# 431   identifier for a page in the Freebase database...
# 444   specify the genome assembly on which the featu...
# 468   orthologous gene in another species (use with ...
# 482   identifier for journal articles/abstracts in P...
# 487            the taxon in which the item can be found
# 515                         part of full name of person
# 516   first name or another given name of this perso...
# 583   date or point in time that information was ret...
# 616                            taxon identifier in GBIF
# 622   should be used for Internet URLs as references...
# 651   indicates that the property value is determine...
# 676    primary topic of a work (see also P180: depicts)
# 687   identifier for a scientific work issued by Pub...
# 720   this category combines (intersects) these two ...
# 721   catalog for the item, or, as a qualifier of P5...
# 739   the item (institution, law, public office, pub...
# 792          chromosome on which an entity is localized
# 814   number of people inhabiting the place; number ...
# 819   quantitative measure of one's game-playing abi...
# 921   measurement of the brightness of an astronomic...
# 929   passband used to isolate particular sections o...
# 1038                  work where this item is described
# 1102  language(s) that a person or a people speaks, ...
# 1120  larger work that a given work was published in...
# 1122  heritage designation of a cultural or natural ...
# 1135  official name of the subject in its official l...
# 1161  published title of a work, such as a newspaper...
# 1184  position of an item in its parent series (most...
# 1205   identifier in the GeoNames geographical database
# 1272  content specialist responsible for this collec...
# 1412  name by which a subject is recorded in a datab...
# 1516  use as qualifier to indicate how the value was...
# 1665  string to store unspecified author or editor n...
# 1781                          parallax of nearest stars
# 1782                            proper motion of a star
# 1783  component of the object's velocity that points...
# 1881  identifier for geographic entities according t...
# 2125         estimated distance to astronomical objects
# 2203  identifier for Google Knowledge Graph API (sta...
# 2380         citation from one creative work to another
# 2407  (URLs only) used to link two items, indicating...
# 2584  identifier for an astronomical object, in the ...
# 4091  identifier for a person on The Peerage genealo...
# 4108  URL of source to indicate the page or revision...
# 5261        identifier of a publication in ResearchGate
# 5552  unique identifier for a work in the Dimensions...
# 5627               astronomical equivalent of longitude
# 5628                astronomical equivalent of latitude
# 5629         epoch of an astronomical object coordinate
# 7164  entity on WorldCat. Use P243 OCLC control numb...
#
#                                                examples
# 5            state, land, sovereign state, host country
# 6     graph, illustration, screen capture, screensho...
# 7     birth location, birthplace, location of birth,...
# 9     intersex, male, man, woman, sex, gender, femal...
# 13    citizenship, (legal) nationality, citizen of, ...
# 15    member of, type, is a, is a type of, type of, ...
# 24    writer, authors, creator, written by, by, writ...
# 27    team, sport team, player of, club played for, ...
# 30                                part of constellation
# 34    faculty, education, alma mater, alumna of, alu...
# 50                  taxonomic rank, rank, type of taxon
# 51    craft, profession, work, job, career, employ, ...
# 52    employed by, worked at, worked for, working at...
# 70    city, town, locality, administrative territori...
# 77    Wikimedia project, Wikipedia project, import f...
# 82    split from, predecessor, preceded by, succeeds...
# 83    comes before, continued as, next, next element...
# 94                           higher taxon, taxon parent
# 111   archives, art collection, museum collection, G...
# 125   VIAF, Virtual International Authority File, VI...
# 133   correct name (ICNafp), Latin name of a taxon (...
# 134   GND, GND ID, GND identifier, Integrated Author...
# 154   in statement, originating source, source of claim
# 166   neighborhood, locality, venue, event location,...
# 169   ⊆, sc, ⊂, form of, has superclass, hyponym of,...
# 170   PIN Code, post code, postal index number, post...
# 183   page, p., pages, page number, page numbers, pg...
# 192                                                 NaN
# 193                          UniProtKB accession number
# 197                           Digital Object Identifier
# 201   in, chain, contained within, merged into, merg...
# 209                        category Commons, commonscat
# 229   language, audio language, available in, broadc...
# 241                       time zone, time, timezone, TZ
# 250                                         no., number
# 270   standard, method, methodology, rationale, just...
# 286      tome, vol., volume of a book, volume of serial
# 303   Open Researcher and Contributor ID, ORCID, Ope...
# 329   comprised of, has member, contains, has ingred...
# 330   register, opus number, astronomical catalog, c...
# 368   DOB, birth date, birth year, birthdate, birthy...
# 369   DOD, dead, death, death date, died on, year of...
# 370   foundation, formation, introduction, formed in...
# 374   publication, dop, published, initial release, ...
# 377   introduction, from, began, beginning, building...
# 378   to, until, ending, cease date, cease operation...
# 379   date, year, time, when, as of, at time, by dat...
# 411   position, location, geolocation, co-ordinate l...
# 427                   play, sports, plays, sport played
# 428   in, for, scope, used for, applicable for, appl...
# 431                  Freebase identifier, MID, Freebase
# 444                                     GenLoc assembly
# 468                                                 NaN
# 482                       PMID, PubMed reference number
# 487                  found in species, present in taxon
# 515                                  surname, last name
# 516   name, Christian name, first name, forename, mi...
# 583   access date, accessdate, accessed, consulted, ...
# 616   GBIF ID, Global Biodiversity Information Facil...
# 622   website, URL, ref, url, Uniform Resource Locat...
# 651                   heuristic, heuristically based on
# 676   subject, artistic theme, topic, sitter, theme,...
# 687   PMC ID, PubMed Central ID, PubMed Central refe...
# 720   category intersects topics, cct, combines topi...
# 721           exhibition catalogue, catalogue, registry
# 739   applies to place, jurisdiction, applied to jur...
# 792                                       on chromosome
# 814                       human population, inhabitants
# 819                                                 NaN
# 921                                                 NaN
# 929              filter, colour filter, wavelength band
# 1038  subject of, entry, described by biography, des...
# 1102  language, used language, second language, lang...
# 1120  album, venue, music album, part of work, artic...
# 1122  designation, protection, heritage status, heri...
# 1135  legal name, name, full title, be named, comple...
# 1161  article, full title, headline, known as, origi...
# 1184  #, index, rank, number, n°, nº, №, num., ordin...
# 1205                                           GeoNames
# 1272  keeper, biocurator, curated by, curation autho...
# 1412  authorized access point, credited as, authoriz...
# 1516  sic, as, [sic], author statement, credited as,...
# 1665  author string, creator name string, editor nam...
# 1781                              astronomical parallax
# 1782                                                NaN
# 1783                                                NaN
# 1881  GNS UFI, Unique Feature Identifier, GEOnet Nam...
# 2125  angular diameter distance, comoving distance, ...
# 2203                   AG, GKG ID, KG ID, KG MID, kgmid
# 2380                   bibliographic citation, citation
# 2407  same as, the same as, same meaning, sameas, sk...
# 2584                                             SIMBAD
# 4091                           Peerage person ID, TP id
# 4108  import URL from a Wikimedia project, reference...
# 5261  ResearchGate ID, ResearchGate publication iden...
# 5552                                                NaN
# 5627                        Longitude of Ascending Node
# 5628                                                NaN
# 5629                                                NaN
# 7164                  WorldCat ID, WorldCat Identity ID

# %%
to_remove = ['country', 
             'image',
             'place of birth',
             'sex or gender',
             'country of citizenship',
             'author',
             'member of sports team',
             'constellation',
             'educated at',
             'taxon rank',
             'occupation',
             'employer',
             'located in the administrative territorial entity',
             'imported from Wikimedia project',
             'collection',
             'VIAF ID',
             'GND ID',
             'stated in',
             'location',
             'postal code',
             'page(s)',
             'Entrez Gene ID',
             'UniProt protein ID',
             'DOI',
             'language of work or name',
             'located in time zone',
             'issue',
             'determination method',
             
             
            
            ]
# Out:
# 100

# %% [markdown]
# # Get wikidata ID

# %%
TERM_LIST = '../01_make_matching_list/matching_list.csv'
WIKIDATA_DICT = './wikidata_id.csv'

# %%
matching_list = pd.read_csv(TERM_LIST,dtype={'wiki_title': str})

pagetitle_qid_dict = pd.read_csv(WIKIDATA_DICT, delimiter='\t', header=None, index_col=0).to_dict()[1]
matching_list['QID'] = matching_list['term'].map(pagetitle_qid_dict)

# %%
matching_list.QID.notna()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 40131    False
# 40132    False
# 40133    False
# 40134    False
# 40135    False
# Name: QID, Length: 40136, dtype: bool

# %%
terms = matching_list[matching_list.wiki_title.notna()].wiki_title.values
terms
# Out:
# array(['Water', 'Primary alcohol', 'Alcohol', ..., 'Hip', 'Cell membrane',
#        'PGS'], dtype=object)

# %%
import requests 
import urllib
import re 
from bs4 import BeautifulSoup

def get_wikidata_id(term):
    
    encoded_term = urllib.parse.quote(term)

    url = f"https://en.wikipedia.org/w/api.php?action=query&format=json&prop=pageprops&ppprop=wikibase_item&redirects=1&titles={encoded_term}"
    html = requests.get(url)
    soup = BeautifulSoup(html.text, 'html.parser').get_text()
    
    wikidata_id = re.findall('wikibase_item\"\:\"(.*)?\".*', soup)
    
    if wikidata_id != []:
        return wikidata_id[0]

# %%
# find wikidata ID for all terms
from tqdm import tqdm

wikidata_ids = []
not_found = []
for term in tqdm(terms):
    wikidata_id = get_wikidata_id(term)
    if wikidata_id != None: 
        wikidata_ids.append(wikidata_id)
    else:
        not_found.append(term)
        
        
        
# add wikititle for each term
for term in tqdm(matching_list[matching_list.wiki_title.isna()].term.values):
    wiki_title = find_wiki_title(term)
    if wiki_title:
        wiki_title_dict.update({term:wiki_title})
# Out:
# 100%|██████████| 8573/8573 [36:41<00:00,  3.89it/s]

# %%
not_found
# Out:
# ['Ω−ωf']

# %% [markdown]
# # Get properties

# %%
def retrieve_value_P(P):
    for i in range(len(all_wikidata_properties)):
        if P == all_wikidata_properties['property_ID'][i]:
            return all_wikidata_properties['property_name'][i]


def retrieve_value_Q(Q):    
    url = f"https://www.wikidata.org/w/api.php?action=wbgetentities&format=json&props=labels&languages=en&ids={Q}"
    json_response = requests.get(url).json()
    entities = json_response.get('entities')
    
    entity = entities.get(Q)
    if entity:
        labels = entity.get('labels')
        if labels:
            en = labels.get('en')
            if en:
                value = en.get('value')
                return value 


def get_all_ItemProperties(wikidata_item, wikidata_id):
    url = "https://www.wikidata.org/w/api.php?action=wbgetclaims&format=json&entity="+wikidata_id
    json_response = requests.get(url).json()

    properties = [*json_response.get('claims').values()]
    
    res = np.empty(shape=[0, 3])
    
    for p in properties:   
        for d in p: 
            dict_ = d['mainsnak']
        
            # ignore if not a wikibase item
            if dict_['datatype'] != 'wikibase-item' or dict_['snaktype'] != 'value':
                continue 
                
            # replace all the wikidataItem ID by wikidataItem name          
            property_value = retrieve_value_Q(dict_['datavalue']['value']['id'])
            
            if property_value is None:
                continue
            
            # find property value in the previous lookup table
            property_ = retrieve_value_P(dict_['property'])
            
            row_to_append = [wikidata_item, property_, property_value]
  
            res = np.append(res, [row_to_append], 0)  
  
    return res

# %%
# remove the entities without wikidata ID
pagetitle = [term for term in terms if term not in not_found]

# conbine the entities and their corresponding ID as dictionary
dict_pagetitle_qid = dict(zip(pagetitle, wikidata_ids))

# %%
dict_pagetitle_qid
# Out:
# {'Water': 'Q283',
#  'Primary alcohol': 'Q2832210',
#  'Alcohol': 'Q156',
#  'Molecule': 'Q11369',
#  'Absorption': 'Q224058',
#  'Statistical mechanics': 'Q188715',
#  'Phase transition': 'Q185357',
#  'Partition function': 'Q1182682',
#  'Spin': 'Q229949',
#  'Aluminium': 'Q663',
#  'Copper': 'Q753',
#  'Shot (pellet)': 'Q278938',
#  'Inorganic waste': 'Q98079057',
#  'Masonry': 'Q272999',
#  'Concrete': 'Q22657',
#  'Particle': 'Q1621273',
#  'LES': 'Q297648',
#  'Personal digital assistant': 'Q162768',
#  'Fluid': 'Q102205',
#  'DEM (disambiguation)': 'Q351071',
#  'Gas': 'Q11432',
#  'D2': 'Q232274',
#  'INS': 'Q195126',
#  'H2': 'Q249260',
#  'Neutron spectroscopy': 'Q7003117',
#  'MOF': 'Q406030',
#  'Weak interaction': 'Q11418',
#  'Liquid': 'Q11435',
#  'Grain': 'Q2995529',
#  'Oxygen': 'Q629',
#  'Ion': 'Q36496',
#  'Grain growth': 'Q1492573',
#  'Variational principle': 'Q745215',
#  'Approach': 'Q4781711',
#  'Action (physics)': 'Q846785',
#  'Lagrangian': 'Q6472692',
#  'Hamiltonian mechanics': 'Q477921',
#  'Pendulum': 'Q20702',
#  'Planet': 'Q634',
#  'Wind wave': 'Q165848',
#  'Phenomenon': 'Q483247',
#  'Framework': 'Q1289773',
#  'System': 'Q58778',
#  'Numerical analysis': 'Q11216',
#  'Physisorption': 'Q354417',
#  'N2': 'Q357501',
#  'CO': 'Q210804',
#  'Carbon dioxide': 'Q1997',
#  'Methane': 'Q37129',
#  'NH 3': 'Q6954226',
#  'SO2': 'Q2207407',
#  'Adsorption': 'Q180254',
#  'Doping': 'Q1179459',
#  'Graphene': 'Q169917',
#  'Substitution reaction': 'Q503396',
#  'Markov chain': 'Q176645',
#  'Gas-cooled reactor': 'Q3100709',
#  'Coolant': 'Q1056832',
#  'Neutron moderator': 'Q466714',
#  'Neutron': 'Q2348',
#  'Carbon monoxide': 'Q2025',
#  'Atmosphere of Earth': 'Q3230',
#  'Graphite': 'Q5309',
#  'Nitrogen': 'Q627',
#  'Reactor': 'Q15841852',
#  'Ls': 'Q283503',
#  'Finite difference method': 'Q1147751',
#  'Pipe': 'Q234455',
#  'RCS': 'Q361433',
#  'Alloy': 'Q37756',
#  'Atmospheric model': 'Q4817115',
#  'Mesh': 'Q24503377',
#  'Calculus of variations': 'Q216861',
#  'Sphere': 'Q12507',
#  'Forcing': 'Q5467581',
#  'Damping': 'Q1127660',
#  'Kelvin wave': 'Q1738426',
#  'Natural frequency': 'Q946764',
#  'Omega': 'Q9890',
#  'Wind': 'Q8094',
#  'Waves': 'Q1210948',
#  'Chlorine': 'Q688',
#  'Probability distribution': 'Q200726',
#  'Numerical sign problem': 'Q7069666',
#  'Distribution': 'Q225802',
#  'Laser': 'Q38867',
#  'Channel': 'Q425520',
#  'Chirp': 'Q27304',
#  'Fragmentation': 'Q297903',
#  'Reaction rate': 'Q3394849',
#  'Gas exchange': 'Q1146120',
#  'Chemical reaction': 'Q36534',
#  'Computational fluid dynamics': 'Q815820',
#  'Direct numerical simulation': 'Q1227572',
#  'Domain Name System': 'Q8767',
#  'Molecular diffusion': 'Q17104113',
#  'Transport phenomena': 'Q679643',
#  'Semiconductor': 'Q11456',
#  'Transition metal': 'Q19588',
#  'CDS': 'Q233280',
#  'Gan': 'Q228248',
#  'Titanium dioxide': 'Q193521',
#  'Electron': 'Q2225',
#  'Nuclear reactor core': 'Q1353262',
#  'Nuclear reactor': 'Q80877',
#  'Uam': 'Q7876347',
#  'Tsunami': 'Q8070',
#  'Solar cell': 'Q58803',
#  'Cell': 'Q2349697',
#  'Chirality (chemistry)': 'Q214514',
#  'Stereoisomerism': 'Q47455153',
#  'Enantiomer': 'Q494483',
#  'Enantiomeric excess': 'Q568761',
#  'Benchmark': 'Q577395',
#  'Squid': 'Q81900',
#  'Hamiltonian': 'Q411492',
#  'Configuration interaction': 'Q900672',
#  'CI': 'Q219118',
#  'Physics': 'Q413',
#  'Crystal': 'Q43533',
#  'Oxide': 'Q50690',
#  'TI': 'Q219218',
#  'Titanium': 'Q716',
#  'Matrix': 'Q190069',
#  'Y': 'Q9973',
#  'O': 'Q9941',
#  'Pyrochlore': 'Q417202',
#  'Irradiation': 'Q2737837',
#  'ITER': 'Q191788',
#  'Vessel': 'Q6661273',
#  'Helium': 'Q560',
#  'Cooling system': 'Q5167499',
#  'Divertor': 'Q1230603',
#  'Tritium': 'Q54389',
#  'Dust': 'Q165632',
#  'Carbon': 'Q623',
#  'Saft': 'Q1903978',
#  'Perturbation theory': 'Q10886678',
#  'Hard spheres': 'Q2435125',
#  'Argon': 'Q696',
#  'Alkane': 'Q41581',
#  'Bead': 'Q1053956',
#  'Cysteine': 'Q186474',
#  'Purine': 'Q188261',
#  'Tautomer': 'Q334640',
#  'Hydrogen': 'Q556',
#  'Molecular dynamics': 'Q901663',
#  'Isotopes of molybdenum': 'Q469900',
#  'Boron': 'Q618',
#  'Sodium': 'Q658',
#  'Glass': 'Q11469',
#  'Aluminium oxide': 'Q177342',
#  'Albite': 'Q182264',
#  'Mathematical model': 'Q486902',
#  'Algorithm': 'Q8366',
#  'Segment': 'Q258480',
#  'Magnetic field': 'Q11408',
#  'Yield (chemistry)': 'Q777948',
#  'Alpha': 'Q9887',
#  'B': 'Q9705',
#  'Electron magnetic moment': 'Q13534105',
#  'Reducing agent': 'Q216830',
#  'Push-to-talk': 'Q178127',
#  'Formaldehyde': 'Q161210',
#  'Formic acid': 'Q161233',
#  'Methanol': 'Q14982',
#  'Radical': 'Q2125865',
#  'RM': 'Q225151',
#  'Saturated calomel electrode': 'Q898591',
#  'Data set': 'Q1172284',
#  'Simulation': 'Q45045',
#  'Volta potential': 'Q746577',
#  'Psi (Greek)': 'Q14432',
#  'Voltage': 'Q25428',
#  'Metal': 'Q11426',
#  'Central processing unit': 'Q5300',
#  'Parallel computing': 'Q232661',
#  'Parametrization (geometry)': 'Q3290922',
#  'Flow': 'Q8961886',
#  'P-box': 'Q7116922',
#  'Film': 'Q11424',
#  'Atom': 'Q9121',
#  'Glossary of computer graphics': 'Q25106492',
#  'Surface diffusion': 'Q3027666',
#  'Thin film': 'Q1137203',
#  'Icosane': 'Q150925',
#  'Vapor pressure': 'Q2661322',
#  'Hydrogen atom': 'Q6643508',
#  'Carbon unit': 'Q97144165',
#  'Wall': 'Q42948',
#  'Two-phase flow': 'Q232997',
#  'Surface tension': 'Q170749',
#  'Capillary wave': 'Q15143885',
#  'Uranium carbide': 'Q2937977',
#  'Pebble-bed reactor': 'Q1622414',
#  'Uranium dioxide': 'Q378379',
#  'GFR': 'Q450207',
#  'High-temperature gas reactor': 'Q1204277',
#  'Carbide': 'Q241906',
#  'Fuel': 'Q42501',
#  'XC': 'Q349855',
#  'Burnup': 'Q306811',
#  'Actinide': 'Q19577',
#  'DFT': 'Q258603',
#  'Density functional theory': 'Q1048589',
#  'Hydride': 'Q106520',
#  'Zirconium': 'Q1038',
#  'Cladding': 'Q1094635',
#  'DHC': 'Q175308',
#  'Thermal expansion': 'Q6583695',
#  'Surfactant': 'Q191154',
#  'Acid': 'Q11158',
#  'Nonoxynols': 'Q72426',
#  'Quaternary ammonium cation': 'Q420401',
#  'Amine': 'Q167198',
#  'Emulsion': 'Q187634',
#  'Cis': 'Q299322',
#  'Statistical model': 'Q3284399',
#  'Query': 'Q7385',
#  'Model': 'Q234018',
#  'Informatics': 'Q4027615',
#  'Analytics': 'Q485396',
#  'Pore': 'Q640125',
#  'Cellular': 'Q1178030',
#  'Crack': 'Q225899',
#  'Redox': 'Q82682',
#  'Optical properties': 'Q55643261',
#  'Förster resonance energy transfer': 'Q367473',
#  'Spectral line': 'Q212111',
#  'Quantum electrodynamics': 'Q234881',
#  'QED': 'Q243414',
#  'Light-harvesting complex': 'Q355270',
#  'Energy': 'Q11379',
#  'Photon': 'Q3198',
#  'Comparative analysis': 'Q1085187',
#  'FM': 'Q210319',
#  'Fe': 'Q224777',
#  'Node': 'Q2128997',
#  'Harmonic superspace': 'Q5659289',
#  'Gauge theory': 'Q214850',
#  'Propagator': 'Q302518',
#  'DG': 'Q235268',
#  'Shallow water equations': 'Q4008384',
#  'Courant–Friedrichs–Lewy condition': 'Q1023483',
#  'Supersymmetry': 'Q193442',
#  'Susy': 'Q2369839',
#  'Sfermion': 'Q2347008',
#  'Evolutionary algorithm': 'Q14489129',
#  'Optimization problem': 'Q984063',
#  'Emo': 'Q10926',
#  'Topological insulator': 'Q1488689',
#  'TIS': 'Q405178',
#  'Spin–orbit interaction': 'Q1570979',
#  'Angle-resolved photoemission spectroscopy': 'Q1000635',
#  'Ab initio': 'Q46310',
#  'Magnetism': 'Q3294789',
#  'Superconductivity': 'Q124131',
#  'Ferromagnetism': 'Q184207',
#  'TM': 'Q218975',
#  'Hall effect': 'Q10656',
#  'Majorana fermion': 'Q1065883',
#  'Wire': 'Q551997',
#  'Thinning': 'Q1266974',
#  'Fracture': 'Q5120022',
#  'Ingress': 'Q15820139',
#  'Concrete cover': 'Q831627',
#  'Hooks': 'Q415670',
#  'Beams': 'Q4876226',
#  'Column': 'Q4817',
#  'Linear model': 'Q3339222',
#  'Inference': 'Q408386',
#  'Lead': 'Q708',
#  'Churn': 'Q5118298',
#  'Slug': 'Q1953597',
#  'Database': 'Q8513',
#  'Wasi': 'Q16891938',
#  'Nomad': 'Q128393',
#  'Sea bass': 'Q1248017',
#  'BB': 'Q218166',
#  'Rationalization': 'Q298256',
#  'Supply': 'Q11827939',
#  'Case study': 'Q155207',
#  'E-procurement': 'Q377505',
#  'Supply chain': 'Q1824206',
#  'Feature extraction': 'Q1026626',
#  'Deep learning': 'Q197536',
#  'Feature': 'Q16782317',
#  'Performance': 'Q35140',
#  'Real-time computing': 'Q3988',
#  'Method': 'Q12221772',
#  'Mineral': 'Q7946',
#  'Semantic network': 'Q1045785',
#  'Ejection': 'Q5350110',
#  'Corrosion': 'Q137056',
#  'Diffusion barrier': 'Q5275435',
#  'Anodizing': 'Q567502',
#  'Electrolyte': 'Q162908',
#  'Polymer': 'Q81163',
#  'Chemical vapor deposition': 'Q505668',
#  'Fluidized bed': 'Q2666694',
#  'Carbon nanotube': 'Q1778729',
#  'CNTS': 'Q29371940',
#  'Trial and error': 'Q2219080',
#  'Hidden node problem': 'Q2565413',
#  'Generalization': 'Q170084',
#  'Elm': 'Q131113',
#  'Silicon dioxide': 'Q116269',
#  'Bulk': 'Q343050',
#  'Weakening': 'Q27787163',
#  'Trapped': 'Q410733',
#  'Relative permeability': 'Q7310797',
#  'Electrical resistivity and conductivity': 'Q65402698',
#  'Ferrite': 'Q341055',
#  'Austenite': 'Q487286',
#  'Paramagnetism': 'Q188479',
#  'Decarburization': 'Q838577',
#  'Steel': 'Q11427',
#  'Finite element method': 'Q220184',
#  'Microstructure': 'Q1498213',
#  'Sensor': 'Q167676',
#  'Monte Carlo algorithm': 'Q15238499',
#  'Conjugate gradient method': 'Q1191895',
#  'Box': 'Q188075',
#  'Evac': 'Q5415216',
#  'He': 'Q1563477',
#  'Tevatron': 'Q944533',
#  'Large Hadron Collider': 'Q40605',
#  'Hadron collider': 'Q16964297',
#  'Higgs boson': 'Q402',
#  'Standard Model': 'Q18338',
#  'SM': 'Q224469',
#  'Higgs': 'Q297293',
#  'Reaction': 'Q69314267',
#  'Norbornene': 'Q420176',
#  'Norbornadiene': 'Q726795',
#  'Transience': 'Q2449174',
#  'Picket fence': 'Q3487546',
#  'Double-exchange mechanism': 'Q5299593',
#  'Electron transfer': 'Q902898',
#  'Mo': 'Q218120',
#  'Replacement': 'Q396788',
#  'Iron': 'Q677',
#  'Mössbauer spectroscopy': 'Q899927',
#  'Compound': 'Q1121905',
#  'CA': 'Q192996',
#  'SR': 'Q218008',
#  'BA': 'Q21152809',
#  'Inverse problem': 'Q1567213',
#  'Experimental data': 'Q5421151',
#  'Potentiometer': 'Q187868',
#  'Parameter': 'Q1413083',
#  'Genetic algorithm': 'Q187787',
#  'GA': 'Q224461',
#  'Synthetic data': 'Q7662746',
#  'Quantum vacuum state': 'Q766202',
#  'Vacuum': 'Q11475',
#  'Unpaired electron': 'Q374793',
#  'Thermal oxidation': 'Q1549368',
#  'Electric charge': 'Q1111',
#  'Thrombus': 'Q1588755',
#  'GP': 'Q223811',
#  'Dirac equation': 'Q272621',
#  'Pauli equation': 'Q604572',
#  'Object': 'Q2011843',
#  'Lattice': 'Q2754968',
#  'Lattice model': 'Q6497122',
#  'Polynomial expansion': 'Q6452866',
#  'Irreducible representation': 'Q13690522',
#  'H': 'Q9914',
#  'Vector meson': 'Q2748910',
#  'Variable': 'Q10954303',
#  'Metric (mathematics)': 'Q865746',
#  'Analysis': 'Q217602',
#  'Standard algorithms': 'Q7598328',
#  'Training, validation, and test sets': 'Q3985153',
#  'K-means clustering': 'Q310401',
#  'Hyperparameter optimization': 'Q48996162',
#  'Old age': 'Q191089',
#  'Patient': 'Q181600',
#  'Microphone': 'Q46384',
#  'Speaker': 'Q253510',
#  'Monitor': 'Q157119',
#  'Communication': 'Q11024',
#  'Robot': 'Q11012',
#  'Model (art)': 'Q1630100',
#  'Baryon': 'Q159731',
#  'Lambda': 'Q10897',
#  'Sigma': 'Q14413',
#  'Meson': 'Q102742',
#  'Pi (disambiguation)': 'Q14411',
#  'Rho': 'Q14412',
#  'Eta': 'Q14396',
#  'K': 'Q9922',
#  'Hadron': 'Q101667',
#  'Kaon': 'Q843503',
#  'High-energy nuclear physics': 'Q12416032',
#  'Collision': 'Q238053',
#  'Quantum chromodynamics': 'Q238170',
#  'Step-growth polymerization': 'Q901428',
#  'Radical polymerization': 'Q2620998',
#  'Polyester': 'Q188245',
#  'Polyamide': 'Q145273',
#  'Epoxies': 'Q464392',
#  'Solution': 'Q5447188',
#  'Dispersed media': 'Q12101201',
#  'Dispersion': 'Q219345',
#  'Bulk polymerization': 'Q6137196',
#  'Polymerization': 'Q181898',
#  'Dilution': 'Q16033661',
#  'Reagent': 'Q2356542',
#  'Solvent': 'Q146505',
#  'Drop (liquid)': 'Q185789',
#  'Crystal structure': 'Q895901',
#  'Energy conservation': 'Q380170',
#  'Friction': 'Q82580',
#  'Dissipation': 'Q898440',
#  'Copolymer': 'Q421281',
#  'Acrylate': 'Q343016',
#  'Water-gas shift reaction': 'Q1466348',
#  'Industrial processes': 'Q1408286',
#  'Catalysis': 'Q82264',
#  'Calcite': 'Q171917',
#  'Heated': 'Q16784458',
#  'Quantum computing': 'Q176555',
#  'Linear particle accelerator': 'Q836828',
#  'Reinforcement learning': 'Q830687',
#  'Pattern matching': 'Q1503724',
#  'Agent': 'Q137372',
#  'Unified framework': 'Q17053202',
#  'Coating': 'Q1570182',
#  'Ra': 'Q1252904',
#  'Roughness': 'Q7370911',
#  'Design methods': 'Q2292993',
#  'Platform': 'Q224617',
#  'Network virtualization': 'Q4112081',
#  'Seesaw mechanism': 'Q1094257',
#  'Quark': 'Q6718',
#  'Yukawa interaction': 'Q31387',
#  'Study': 'Q340383',
#  'Toxicity': 'Q274160',
#  'Algae': 'Q37868',
#  'Isochrysis galbana': 'Q16983663',
#  'Incubation': 'Q241656',
#  'Chloroplast': 'Q47263',
#  'Aerospace': 'Q2876213',
#  'Vehicle': 'Q42889',
#  'Adhesive': 'Q131790',
#  'Fracture toughness': 'Q911969',
#  'Organic': 'Q294310',
#  'Cure (disambiguation)': 'Q353374',
#  'Additive': 'Q404330',
#  'Hybrid material': 'Q2159673',
#  'Thermogravimetric analysis': 'Q902806',
#  'TGA': 'Q297653',
#  'Reducing atmosphere': 'Q7306351',
#  'Weight transfer (dancing)': 'Q7979883',
#  'Perovskite': 'Q409787',
#  'Calcination': 'Q849523',
#  'Conductivity': 'Q1816225',
#  'In situ adaptive tabulation': 'Q6011744',
#  'Solid': 'Q11438',
#  'Modification': 'Q6889353',
#  'Rail': 'Q3417678',
#  'Track': 'Q351303',
#  'Clathrate hydrate': 'Q864080',
#  'Thermal conductivity': 'Q487005',
#  'BIN': 'Q11191244',
#  'Cam': 'Q495933',
#  'Continuous function': 'Q170058',
#  'Least squares': 'Q74304',
#  'Polynomial': 'Q43260',
#  'Coefficient': 'Q50700',
#  'Micelle': 'Q421110',
#  'Dynamic light scattering': 'Q896108',
#  'DSC': 'Q297325',
#  'Self-assembly': 'Q910150',
#  'Doxorubicin': 'Q18936',
#  'Cytotoxicity': 'Q246181',
#  'Hyperthermia': 'Q242165',
#  'Aggregation': 'Q362306',
#  'Coupling': 'Q944517',
#  'Constitutive equation': 'Q1937401',
#  'Porous medium': 'Q3271208',
#  'U': 'Q9747',
#  'Extension': 'Q295785',
#  'Word-sense disambiguation': 'Q48522',
#  'Throttle': 'Q961356',
#  'Warped geometry': 'Q988401',
#  'Localization': 'Q251307',
#  'Toll-like receptor': 'Q408004',
#  'Antigen-presenting cell': 'Q1047791',
#  'TLR9': 'Q15332550',
#  'Clinical trial': 'Q30612',
#  'Adjuvant': 'Q357896',
#  'Model organism': 'Q213907',
#  'Liposome': 'Q410454',
#  'Curse of dimensionality': 'Q1430460',
#  'Support-vector machine': 'Q282453',
#  'Computation': 'Q12525525',
#  'Approximation': 'Q27058',
#  'Partial current': 'Q3694432',
#  'Pit': 'Q417814',
#  'AL': 'Q208534',
#  'Aluminium alloy': 'Q447725',
#  'Current': 'Q226663',
#  'Survey': 'Q1510180',
#  'Social networking service': 'Q3220391',
#  'Mobile app': 'Q620615',
#  'App': 'Q59350',
#  'Knowledge management': 'Q192060',
#  'Kilometre': 'Q828224',
#  'Knowledge management software': 'Q1427675',
#  'KMS': 'Q342468',
#  'Role-based access control': 'Q1702839',
#  'Level-set method': 'Q1751397',
#  'Fast marching method': 'Q5437042',
#  'Level set': 'Q126955',
#  'Area': 'Q11500',
#  'Computer simulation': 'Q925667',
#  'Brass': 'Q39782',
#  'Subtraction': 'Q40754',
#  'Optical microscope': 'Q912313',
#  'TEMS': 'Q7669997',
#  'Scanning electron microscope': 'Q321095',
#  'Microscopy': 'Q1074953',
#  'Microscope': 'Q196538',
#  'Data analysis': 'Q1988917',
#  'Thermalisation': 'Q1347805',
#  'Nuclear reaction': 'Q238323',
#  'Quantum spin liquid': 'Q1661413',
#  'C60': 'Q1022673',
#  'Core': 'Q232469',
#  'Plenum': 'Q1293406',
#  'Silicon': 'Q670',
#  'Mix': 'Q250391',
#  'Air entrainment': 'Q3523286',
#  'Sediment transport': 'Q7445303',
#  'Breaking wave': 'Q661247',
#  'Expectation–maximization algorithm': 'Q1275153',
#  'Nemytskii operator': 'Q6991377',
#  'Molybdenum': 'Q1053',
#  'Capsule': 'Q2477733',
#  'Activation': 'Q4661718',
#  'Radiant exposure': 'Q1418023',
#  'Bloom': 'Q885313',
#  'Rust': 'Q184197',
#  'Pipeline': 'Q250434',
#  'Heat': 'Q44432',
#  'Exhaust gas': 'Q320173',
#  'Binary collision approximation': 'Q4913881',
#  'Coulomb collision': 'Q869411',
#  'Plasma': 'Q105537',
#  'Anomaly detection': 'Q3560506',
#  'Data mining': 'Q172491',
#  'Cluster': 'Q224419',
#  'Anomaly': 'Q225529',
#  'A5': 'Q223922',
#  'Phi': 'Q10029',
#  'Boundary value problem': 'Q1332643',
#  'Prism': 'Q165896',
#  'Transformation matrix': 'Q1482183',
#  'Geometrical optics': 'Q467980',
#  'Effectiveness': 'Q1296024',
#  'Robustness': 'Q403605',
#  'Object point': 'Q28455541',
#  'Image': 'Q478798',
#  'Glasses': 'Q37501',
#  'Indentation hardness': 'Q3150000',
#  'Cathodic protection': 'Q15152527',
#  'ICCP': 'Q5969405',
#  'Degradation': 'Q345280',
#  'Acidification': 'Q4674096',
#  'A': 'Q9659',
#  'Environmental flow': 'Q2259545',
#  'Taylor series': 'Q131187',
#  'Compact star': 'Q368442',
#  'Isogeometric analysis': 'Q17082433',
#  'Surface': 'Q55634432',
#  'Synthetic diamond': 'Q751479',
#  'Diamond': 'Q5283',
#  'Polishing': 'Q1054722',
#  'Coupon': 'Q11034548',
#  'Polished': 'Q7210088',
#  'Isopropyl alcohol': 'Q16392',
#  'Ultrasonic cleaning': 'Q1085360',
#  'Propanol': 'Q3407542',
#  'Cleaning': 'Q17200001',
#  'Lump sum': 'Q2884599',
#  'Principal component analysis': 'Q2873',
#  'PCA': 'Q229117',
#  'Recognition': 'Q13725110',
#  'DNA': 'Q7430',
#  'Peptide': 'Q172847',
#  'LPD': 'Q402859',
#  'Dotma': 'Q5299461',
#  'Dope': 'Q234575',
#  'World Trade Organization': 'Q7825',
#  'MP3': 'Q42591',
#  'Ecolinguistics': 'Q294936',
#  'Video-oculography': 'Q6161730',
#  'Vog': 'Q2896842',
#  'Morphology': 'Q178224',
#  'Stimulation': 'Q4114622',
#  'Electromagnetic field': 'Q177625',
#  'Longitudinal wave': 'Q626707',
#  'Organic matter': 'Q1783121',
#  'Optical pumping': 'Q2027473',
#  'Organic (model)': 'Q7101794',
#  'Biosensor': 'Q669391',
#  'Chemoreceptor': 'Q1069641',
#  'Absorption (electromagnetic radiation)': 'Q905921',
#  'Charge density': 'Q744771',
#  'Kalman filter': 'Q846780',
#  'Cost function': 'Q16769844',
#  'Regression': 'Q234013',
#  'Software development': 'Q638608',
#  'Training': 'Q918385',
#  'Software development process': 'Q2904257',
#  'Software industry': 'Q880371',
#  'Parity': 'Q182627',
#  'Chaos theory': 'Q166314',
#  'Polystyrene': 'Q146243',
#  'Wireless sensor network': 'Q336038',
#  'Wireless ad hoc network': 'Q4085781',
#  'Édouard Manet': 'Q40599',
#  'Routing protocol': 'Q1648707',
#  'Mobile wireless sensor network': 'Q17149548',
#  'Thermodynamic equilibrium': 'Q51363',
#  'DSMC': 'Q5206159',
#  'Molecular vibration': 'Q900121',
#  'Rotational energy': 'Q2140940',
#  'TSH': 'Q395900',
#  'Linear response function': 'Q3261000',
#  'LR': 'Q224289',
#  'Manganese': 'Q731',
#  'MN': 'Q223820',
#  'CCS': 'Q257413',
#  'Caproni Campini N.1': 'Q963609',
#  'Fission': 'Q342433',
#  'Diffusion': 'Q163214',
#  'Bubble': 'Q95695210',
#  'Grain boundary': 'Q900515',
#  'Uranium': 'Q1098',
#  'Loop around': 'Q6675815',
#  'Migration': 'Q1932583',
#  'Xe': 'Q1531352',
#  'VU': 'Q226762',
#  'Rearrangement': 'Q7301458',
#  'Charge': 'Q77076',
#  'Potential': 'Q1202245',
#  'Potential (disambiguation)': 'Q231761',
#  'Surface area': 'Q1379273',
#  'Profile': 'Q61875635',
#  'Sample': 'Q1570376',
#  'R-symmetry': 'Q3928107',
#  'Ionization': 'Q190382',
#  'Return': 'Q264890',
#  'W': 'Q9964',
#  'D': 'Q9884',
#  'C': 'Q9820',
#  'Plate': 'Q415419',
#  'Seismic tomography': 'Q1850768',
#  'X-ray absorption spectroscopy': 'Q903103',
#  'X-ray emission spectroscopy': 'Q1532011',
#  'Eigenvalues and eigenvectors': 'Q190524',
#  'Calculation': 'Q622821',
#  'Deep structure and surface structure': 'Q1412344',
#  'Boundary element method': 'Q1935004',
#  'BEM': 'Q347122',
#  'Fast multipole method': 'Q5437040',
#  'Partial pressure': 'Q27165',
#  'Vapor': 'Q255722',
#  'Phase (matter)': 'Q104837',
#  'Greenhouse gas': 'Q167336',
#  'Sic': 'Q192003',
#  'Aspect-oriented programming': 'Q30267',
#  'AOP': 'Q281659',
#  'NB': 'Q223906',
#  'Grain boundary strengthening': 'Q264845',
#  'Fading': 'Q1196572',
#  'TCR': 'Q413139',
#  'Porosity': 'Q622669',
#  'Knowledge base': 'Q593744',
#  'Expert system': 'Q184609',
#  'Jena': 'Q3150',
#  'Factorization': 'Q188804',
#  'Fragmentation function': 'Q25099950',
#  'Subdivision surface': 'Q1529124',
#  'Model building': 'Q917912',
#  'SPM': 'Q298655',
#  'AFM': 'Q292082',
#  'Crystallization of polymers': 'Q1789148',
#  'Staining': 'Q2332446',
#  'Sample preparation': 'Q2540164',
#  'Crystal growth': 'Q185154',
#  'Melting': 'Q106080',
#  'Solar irradiance': 'Q7556707',
#  'Natural convection': 'Q3285020',
#  'Correlation and dependence': 'Q186290',
#  'The System': 'Q3522944',
#  'Service provider': 'Q2169973',
#  'Global analysis': 'Q17017346',
#  'Neutrino': 'Q2126',
#  'Input device': 'Q864114',
#  'Duct': 'Q5311585',
#  'Sampling (signal processing)': 'Q210868',
#  'Identification': 'Q407776',
#  'Pods': 'Q7207114',
#  'OTS': 'Q403785',
#  'ECD': 'Q1207143',
#  'Through-silicon via': 'Q1578120',
#  'LSM': 'Q1798344',
#  'Jet set': 'Q1259750',
#  'Resonance': 'Q172858',
#  'Normalization': 'Q248604',
#  'Foreign direct investment': 'Q490513',
#  'FDI': 'Q418906',
#  'Wavelet': 'Q831390',
#  'Time series': 'Q186588',
#  'Autocorrelation': 'Q786970',
#  'Charm quark': 'Q6754',
#  'Sum rule': 'Q7636894',
#  'Fermionic condensate': 'Q898383',
#  'Ope': 'Q2288034',
#  'Black hole': 'Q589',
#  'List of relativistic equations': 'Q6636278',
#  'Quantum field theory': 'Q54505',
#  'Wave function': 'Q2362761',
#  'Face detection': 'Q11681085',
#  'Noise reduction': 'Q581861',
#  'Video scaler': 'Q98650565',
#  'Gesture recognition': 'Q1519524',
#  'Astrophysical maser': 'Q1341811',
#  'Oh': 'Q224216',
#  'Neutron star': 'Q4202',
#  'Observation': 'Q193181',
#  'Hydrogen line': 'Q1406191',
#  'Pomeron': 'Q1126045',
#  'Iron(III) chloride': 'Q399771',
#  'PAM': 'Q232847',
#  'Cod': 'Q13194939',
#  'Stress corrosion cracking': 'Q585977',
#  'Inconel': 'Q898562',
#  'Stainless steel': 'Q172587',
#  'Pressurized water reactor': 'Q377968',
#  'Plant': 'Q756',
#  'Review': 'Q265158',
#  'Galerkin method': 'Q1491980',
#  'Adaptive mesh refinement': 'Q4680751',
#  'P': 'Q9946',
#  'PG': 'Q218782',
#  'Diagnosis': 'Q16644043',
#  'Rolling-element bearing': 'Q1335987',
#  'Nanosphere lithography': 'Q17043033',
#  'ICP': 'Q350172',
#  'Polyimide': 'Q145958',
#  'Polyvinyl alcohol': 'Q146339',
#  'Crystallization': 'Q284256',
#  'Lamella': 'Q414194',
#  'Low-carbon economy': 'Q3267905',
#  'Economic development': 'Q4530482',
#  'Technological innovation': 'Q10302305',
#  'Iga': 'Q18381640',
#  'Poisson': 'Q232463',
#  'Non-uniform rational B-spline': 'Q734737',
#  'String cosmology': 'Q279029',
#  'Scalar field': 'Q193460',
#  'CP violation': 'Q12794416',
#  'Brane': 'Q385601',
#  'Babar': 'Q85744715',
#  'Belle': 'Q294042',
#  'Nodal': 'Q15948572',
#  'Mass fraction (chemistry)': 'Q899138',
#  'Foundry': 'Q13883136',
#  'Analytical chemistry': 'Q2346',
#  'Spectrophotometry': 'Q332084',
#  'Cyanocobalamin': 'Q252251',
#  'Ethyl acetate': 'Q407153',
#  'Centrifugation': 'Q1967135',
#  'Decantation': 'Q661953',
#  'Precipitation (chemistry)': 'Q113796',
#  'Residue': 'Q411194',
#  'Acetone': 'Q49546',
#  'Butanol': 'Q663902',
#  'Ammonia': 'Q4087',
#  'Freeze-drying': 'Q723912',
#  'Threshold': 'Q359787',
#  'Pattern recognition': 'Q378859',
#  'Computer vision': 'Q844240',
#  'Tracking': 'Q237984',
#  'Recall (memory)': 'Q18733',
#  'Market segmentation': 'Q363057',
#  'Transverse mode': 'Q597069',
#  'Histogram': 'Q185020',
#  'Fermion': 'Q44363',
#  'Isospin': 'Q836938',
#  'Nucleon': 'Q102165',
#  'Total angular momentum quantum number': 'Q1141095',
#  'Mean-field theory': 'Q626011',
#  'Measurement': 'Q12453',
#  'Eos': 'Q178417',
#  'Mixture': 'Q169336',
#  'Artificial neural network': 'Q192776',
#  'Weight (disambiguation)': 'Q542276',
#  'Multilayer perceptron': 'Q2991667',
#  'Convergence': 'Q176553',
#  'MLP': 'Q237028',
#  'Ann': 'Q2406872',
#  'Stockpile': 'Q2710737',
#  'PH': 'Q40936',
#  'Nuclear fuel': 'Q194523',
#  'ATF': 'Q231220',
#  'Exothermic reaction': 'Q205949',
#  'Oxide dispersion-strengthened alloy': 'Q2042849',
#  'ODS': 'Q345484',
#  'Nanostructure': 'Q1093894',
#  'Balance': 'Q1911050',
#  'Solid solution': 'Q787619',
#  'Radiation': 'Q18335',
#  'Mechanical alloying': 'Q5239697',
#  'Consolidation': 'Q297534',
#  'Swelling': 'Q7655860',
#  'Probabilistic method': 'Q3333679',
#  'Spark plasma sintering': 'Q2307265',
#  'SPS': 'Q298316',
#  'Hip': 'Q193818',
#  'Powder': 'Q2908004',
#  'Mold (disambiguation)': 'Q237063',
#  'Heating element': 'Q610112',
#  'Irradiance': 'Q830654',
#  'Aircraft engine': 'Q743004',
#  'Sound': 'Q11461',
#  'Mean flow': 'Q6803620',
#  'LM': 'Q258030',
#  'SEM': 'Q233287',
#  'Strain': 'Q2353244',
#  'Shear stress': 'Q657936',
#  'Buckling': 'Q693104',
#  'Ros': 'Q408293',
#  'DNA repair': 'Q210538',
#  'Strand': 'Q253279',
#  'DBS': 'Q342642',
#  'AA': 'Q218143',
#  'Photograph': 'Q125191',
#  'Ultrasound': 'Q162564',
#  'Shock wave': 'Q190688',
#  'Cavitation (bone)': 'Q5055163',
#  'Investigation': 'Q345847',
#  'Theory': 'Q17737',
#  'Retrieval': 'Q968112',
#  'Data': 'Q42848',
#  'Homogeneity and heterogeneity': 'Q19933904',
#  'Room temperature': 'Q111092',
#  'Tube': 'Q243046',
#  'Na': 'Q224438',
#  'Immersed boundary method': 'Q11425899',
#  'IBM': 'Q37156',
#  'Structure': 'Q6671777',
#  'Newtonian fluid': 'Q366968',
#  'Motion': 'Q79782',
#  'Period': 'Q103750657',
#  'Frequency': 'Q11652',
#  'Heart rate variability': 'Q933954',
#  'Circulatory system': 'Q11068',
#  'Wavelet transform': 'Q2867',
#  'Phase synchronization': 'Q4420475',
#  'Statistics': 'Q12483',
#  'Yield': 'Q596465',
#  'Production planning': 'Q1386523',
#  'Coordination game': 'Q656316',
#  'Design tool': 'Q17008971',
#  'Culture change': 'Q5193493',
#  'Transport network analysis': 'Q924286',
#  'Jetting': 'Q98069370',
#  'Rolling ball argument': 'Q7361234',
#  'Test': 'Q224615',
#  'Tack': 'Q1573827',
#  'PSA': 'Q226496',
#  'Substrate': 'Q2362549',
#  'Electricity generation': 'Q383973',
#  'Power station': 'Q159719',
#  'Temperature cycling': 'Q7698333',
#  'List of National Roads in Latvia': 'Q934713',
#  'The Material': 'Q2919040',
#  'Technicolor (physics)': 'Q1045880',
#  'ETC': 'Q228387',
#  'Block': 'Q6536648',
#  'Extreme value theory': 'Q729429',
#  'Eva': 'Q225292',
#  'Generalized extreme value distribution': 'Q1617240',
#  'Scattering': 'Q210028',
#  'Gelation': 'Q48995704',
#  'General relativity': 'Q11452',
#  'Lunar Laser Ranging experiment': 'Q94741',
#  'Interpretation': 'Q651448',
#  'Decision problem': 'Q3262192',
#  'SAA': 'Q357558',
#  "Jensen's inequality": 'Q518131',
#  'Premenstrual syndrome': 'Q220193',
#  'Technical support': 'Q366580',
#  'Canter and gallop': 'Q1007807',
#  'Powder metallurgy': 'Q726605',
#  'Hard metal': 'Q5655569',
#  'Green body': 'Q1413470',
#  'Central heating': 'Q843596',
#  'Traction (engineering)': 'Q1852039',
#  'Polyurea': 'Q421717',
#  'Mitigation': 'Q6881760',
#  'Reflection': 'Q120429',
#  'Layer': 'Q254549',
#  'Weathering': 'Q179177',
#  'Chemical substance': 'Q79529',
#  'Penetration': 'Q367837',
#  'Cure': 'Q1595418',
#  'Hole': 'Q20204151',
#  'Base': 'Q575724',
#  'Elliptic flow': 'Q5365798',
#  'Spectra': 'Q7575154',
#  'Hadronization': 'Q1456042',
#  'Quark–gluon plasma': 'Q733096',
#  'Physical model': 'Q11784425',
#  'Viscosity': 'Q128709',
#  'Thermal conduction': 'Q7465774',
#  'Tetrahedron': 'Q160003',
#  'PSPACE': 'Q500716',
#  'Regression analysis': 'Q208042',
#  'Academic journal': 'Q737498',
#  'Vad': 'Q2246409',
#  'Segment (linguistics)': 'Q602418',
#  'Dressing': 'Q1207827',
#  'Parity (physics)': 'Q141160',
#  'Soliton': 'Q464949',
#  'Deep Water': 'Q22932371',
#  'Wave': 'Q37172',
#  'Fluid dynamics': 'Q216320',
#  'Computer-aided design': 'Q184793',
#  'Adaptive algorithm': 'Q1988072',
#  'Estimation theory': 'Q1376021',
#  'Particle filter': 'Q1151499',
#  'Cox': 'Q250048',
#  'PX': 'Q33266',
#  'Soft sensor': 'Q18822403',
#  'PAS': 'Q36544',
#  'Biomimetic material': 'Q4915146',
#  'Electrospinning': 'Q1533542',
#  'Plutonium(IV) oxide': 'Q413258',
#  'Cooling': 'Q3929317',
#  'Freezing': 'Q108000',
#  'Pollen tube': 'Q1429464',
#  'Cell signaling': 'Q210973',
#  'Product (chemistry)': 'Q542929',
#  'Plant reproduction': 'Q2725616',
#  'Sandstone': 'Q13085',
#  'Permeability': 'Q234016',
#  'SDR': 'Q231164',
#  'Nuclear magnetic resonance': 'Q209402',
#  'Calibration': 'Q736777',
#  'CSM': 'Q443616',
#  '3D modeling': 'Q568742',
#  'Abaqus': 'Q728658',
#  'Particle method': 'Q24898874',
#  'Direct simulation Monte Carlo': 'Q4382753',
#  'Analytical technique': 'Q4751159',
#  'Circuit': 'Q474704',
#  'Polyethylene naphthalate': 'Q411472',
#  'Pen': 'Q165447',
#  'Drum': 'Q11404',
#  'Cross-link': 'Q898597',
#  'Exposure': 'Q210027',
#  'Insulator': 'Q1179595',
#  'Evaporator': 'Q1764892',
#  'Shadow mask': 'Q1192335',
#  'Digraph': 'Q446432',
#  'Learning': 'Q133500',
#  'Motion tracking': 'Q6917811',
#  'Head-mounted display': 'Q1333980',
#  'Splitting': 'Q1270054',
#  'Sweep': 'Q1564686',
#  'Cosmic microwave background': 'Q15605',
#  'IRB': 'Q346803',
#  'MBR': 'Q407069',
#  'Proton': 'Q2294',
#  'Etching': 'Q186986',
#  'Spin coating': 'Q1305254',
#  'Chlorobenzene': 'Q407768',
#  'SOC': 'Q295387',
#  'Baking': 'Q720398',
#  'Chloroform': 'Q172275',
#  'Anisole': 'Q312244',
#  'Relational database': 'Q192588',
#  'Web application': 'Q189210',
#  'Quality': 'Q298413',
#  'Project manager': 'Q816432',
#  'Objective': 'Q341954',
#  'Cost': 'Q240673',
#  'Sensitivity analysis': 'Q1889114',
#  'Collocation method': 'Q1779479',
#  'Galerkin': 'Q253717',
#  'CG': 'Q223859',
#  'FR': 'Q224441',
#  ...}

# %%
# check disambiguation page
def is_disambiguation_page(wikidata_id):
    
    url = "https://www.wikidata.org/wiki/" + wikidata_id
    html = requests.get(url)
    soup = BeautifulSoup(html.text, 'html.parser')
    
    div = soup.find("div", {"class": "wikibase-entitytermsview-heading-description"}).text
    
    return div == 'Wikimedia disambiguation page'

# %%
# check disambiguation page from list entities 
to_remove = []

for term, wikidata_id in tqdm(dict_pagetitle_qid.items()):

    if is_disambiguation_page(wikidata_id):
        to_remove.append(term)
# Out:
# 100%|██████████| 6306/6306 [1:17:15<00:00,  1.36it/s]

# %%
to_remove
# Out:
# ['Absorption',
#  'Partition function',
#  'Spin',
#  'LES',
#  'DEM (disambiguation)',
#  'D2',
#  'INS',
#  'H2',
#  'MOF',
#  'Approach',
#  'Lagrangian',
#  'Framework',
#  'N2',
#  'CO',
#  'NH 3',
#  'SO2',
#  'Doping',
#  'Reactor',
#  'Pipe',
#  'RCS',
#  'Forcing',
#  'Waves',
#  'Distribution',
#  'Channel',
#  'Fragmentation',
#  'CDS',
#  'Gan',
#  'Cell',
#  'Benchmark',
#  'Hamiltonian',
#  'CI',
#  'TI',
#  'Matrix',
#  'Vessel',
#  'Cooling system',
#  'Saft',
#  'Segment',
#  'Radical',
#  'RM',
#  'Flow',
#  'P-box',
#  'Carbon unit',
#  'GFR',
#  'XC',
#  'DFT',
#  'Cladding',
#  'DHC',
#  'Cis',
#  'Query',
#  'Model',
#  'Pore',
#  'Cellular',
#  'Crack',
#  'QED',
#  'Comparative analysis',
#  'FM',
#  'Fe',
#  'Node',
#  'DG',
#  'Susy',
#  'TIS',
#  'TM',
#  'Ingress',
#  'Hooks',
#  'Churn',
#  'Wasi',
#  'Sea bass',
#  'BB',
#  'Rationalization',
#  'Supply',
#  'Feature',
#  'Method',
#  'Ejection',
#  'CNTS',
#  'Bulk',
#  'Weakening',
#  'Trapped',
#  'Ferrite',
#  'Evac',
#  'He',
#  'SM',
#  'Higgs',
#  'Reaction',
#  'Transience',
#  'Mo',
#  'Replacement',
#  'Compound',
#  'CA',
#  'SR',
#  'BA',
#  'GA',
#  'GP',
#  'Object',
#  'Lattice',
#  'Lattice model',
#  'Variable',
#  'Speaker',
#  'Monitor',
#  'Pi (disambiguation)',
#  'Dispersion',
#  'Dilution',
#  'Heated',
#  'Agent',
#  'Roughness',
#  'Platform',
#  'Study',
#  'Incubation',
#  'Organic',
#  'Cure (disambiguation)',
#  'Additive',
#  'TGA',
#  'Conductivity',
#  'Modification',
#  'Rail',
#  'Track',
#  'BIN',
#  'DSC',
#  'Aggregation',
#  'Extension',
#  'Localization',
#  'Pit',
#  'AL',
#  'Current',
#  'Survey',
#  'App',
#  'KMS',
#  'TEMS',
#  'C60',
#  'Core',
#  'Plenum',
#  'Mix',
#  'Capsule',
#  'Bloom',
#  'Pipeline',
#  'Plasma',
#  'Cluster',
#  'Anomaly',
#  'A5',
#  'ICCP',
#  'Degradation',
#  'Acidification',
#  'PCA',
#  'Recognition',
#  'LPD',
#  'Dope',
#  'Morphology',
#  'Cost function',
#  'Regression',
#  'Parity',
#  'DSMC',
#  'TSH',
#  'LR',
#  'MN',
#  'CCS',
#  'Fission',
#  'Bubble',
#  'Migration',
#  'Xe',
#  'VU',
#  'Rearrangement',
#  'Charge',
#  'Potential (disambiguation)',
#  'Profile',
#  'Sample',
#  'Return',
#  'Plate',
#  'BEM',
#  'AOP',
#  'NB',
#  'TCR',
#  'SPM',
#  'AFM',
#  'The System',
#  'Duct',
#  'Identification',
#  'Pods',
#  'OTS',
#  'ECD',
#  'LSM',
#  'Normalization',
#  'FDI',
#  'Sum rule',
#  'Oh',
#  'PAM',
#  'PG',
#  'ICP',
#  'Lamella',
#  'Iga',
#  'Poisson',
#  'Belle',
#  'Nodal',
#  'Residue',
#  'Threshold',
#  'Tracking',
#  'Weight (disambiguation)',
#  'Convergence',
#  'MLP',
#  'Ann',
#  'ATF',
#  'ODS',
#  'Balance',
#  'Consolidation',
#  'Swelling',
#  'SPS',
#  'Mold (disambiguation)',
#  'LM',
#  'SEM',
#  'Strain',
#  'Ros',
#  'Strand',
#  'DBS',
#  'AA',
#  'Investigation',
#  'Retrieval',
#  'Tube',
#  'Na',
#  'Period',
#  'Yield',
#  'Jetting',
#  'Test',
#  'Tack',
#  'PSA',
#  'Substrate',
#  'ETC',
#  'Block',
#  'Eva',
#  'Interpretation',
#  'SAA',
#  'Hard metal',
#  'Mitigation',
#  'Reflection',
#  'Layer',
#  'Penetration',
#  'Base',
#  'Spectra',
#  'Vad',
#  'Dressing',
#  'Deep Water',
#  'Cox',
#  'PX',
#  'PAS',
#  'Permeability',
#  'SDR',
#  'CSM',
#  'Circuit',
#  'Exposure',
#  'Insulator',
#  'Digraph',
#  'Motion tracking',
#  'Splitting',
#  'Sweep',
#  'IRB',
#  'MBR',
#  'SOC',
#  'Quality',
#  'Objective',
#  'Galerkin',
#  'CG',
#  'FR',
#  'Mil',
#  'Process',
#  'Composite',
#  'Infection (disambiguation)',
#  'Defect',
#  'Void',
#  'Charm',
#  'Vo',
#  'Oi',
#  'Singularity',
#  'Dissociation',
#  'Romp',
#  'Coordination',
#  'Deactivation',
#  'LMS',
#  'CGM',
#  'Alkylamines',
#  'MD',
#  'Ni',
#  'Element',
#  'Scene',
#  'Classification',
#  'GDC',
#  'Polarization',
#  'Jerks',
#  'SV',
#  'MF',
#  'SA',
#  'Jerk',
#  'Nucleus',
#  'B0',
#  'Decay',
#  'Pav',
#  'Inverse',
#  'Roll',
#  'SN',
#  'ZN',
#  'AG',
#  'Fib',
#  'CT',
#  'FEM',
#  'Fabrication',
#  'BCC',
#  'Phosphorous',
#  'Transform',
#  'Time scale',
#  'Imaging',
#  'O2',
#  'Module',
#  'Scale up',
#  'Response rate',
#  'HPC',
#  'Simple',
#  'Quantization',
#  'Production',
#  'CRG',
#  'BN',
#  'Clustering',
#  'IAS',
#  'Shell model',
#  'EDS',
#  'Stem',
#  'Tem',
#  'Hybrid',
#  'Pe',
#  'Circ',
#  'ALD',
#  'Functional',
#  'PDES',
#  'Melt',
#  'JPC',
#  'GT',
#  'Graph',
#  'IDS',
#  'Poly',
#  'Hema',
#  'FEA',
#  'Shell',
#  'PL',
#  'EIS',
#  'Instrument',
#  'Upper atmosphere',
#  'W/o',
#  'CMC',
#  'Quantitative analysis',
#  'Metalization',
#  'Odes',
#  'Site',
#  'Artifact',
#  'Propagation',
#  'Enrichment',
#  'Phaser',
#  'Mac',
#  'Pulp',
#  'SLR',
#  'Us',
#  'Crossover',
#  'TH',
#  'Passenger safety',
#  'Atomization',
#  'DPD',
#  'Put',
#  'NTA',
#  'Chamber',
#  'Chambers',
#  'TFM',
#  'Grid',
#  'Application',
#  'Virtual server',
#  'NL',
#  'NS',
#  'STL',
#  'Vero',
#  'Dag',
#  'Schmidt',
#  'TPA',
#  'RH',
#  'DOS (disambiguation)',
#  'Pill',
#  'Vissim',
#  'Driver',
#  'Deployment',
#  'SNR',
#  'DP',
#  'Mass (disambiguation)',
#  'ENU (disambiguation)',
#  'Termination',
#  'Plane',
#  'Mola',
#  'Dems',
#  'Inequality',
#  'Surf',
#  'SVM',
#  'PC',
#  'Interface',
#  'SB',
#  'MSE',
#  'LCS',
#  'Moment',
#  'Critical density',
#  'Buffer',
#  'Transmission',
#  'Dea',
#  'Equivalence theorem',
#  'H0',
#  'LBP',
#  'ER',
#  'Preprocessing',
#  'Batch',
#  'SE',
#  'CTF',
#  'PSD',
#  'Render',
#  'ROP',
#  'Kernel',
#  'PT',
#  'MGS',
#  'Protocol',
#  'Network',
#  'Segregation',
#  'Phase change',
#  'DM',
#  'Was',
#  'AMN',
#  'HD',
#  'Fed',
#  'AT',
#  'ND',
#  'DTD',
#  'APC',
#  'FAP',
#  'AAPC',
#  'JT',
#  'Tremor (disambiguation)',
#  'WT',
#  'DDS',
#  'HH',
#  'GH',
#  'Aku',
#  'FD',
#  'IDC',
#  'DGS',
#  'EMD',
#  'CHS',
#  'As',
#  'CP',
#  'McLeod',
#  'MJD',
#  'XLT',
#  'MED',
#  'FS',
#  'PLS',
#  'Retinal degeneration',
#  'FEO',
#  'PDB',
#  'HMS',
#  'PPK',
#  'Trauma',
#  'WD',
#  'Sudden death',
#  'Ara',
#  'GD',
#  'Macular dystrophy',
#  'AAS',
#  'HPA',
#  'CHM',
#  'NDP',
#  'Duchenne',
#  'WAGR',
#  'MLD',
#  'Xai',
#  'CES',
#  'GS',
#  'FPC',
#  'TS',
#  'TCD',
#  'LGS',
#  'HBL',
#  'GTD',
#  'Ado',
#  'Norrie',
#  'Junctional epidermolysis bullosa',
#  'DMS',
#  'Ptosis',
#  'CLD',
#  'CRC',
#  'HCP',
#  'Hus',
#  'Depression',
#  'CDM',
#  'HC',
#  'Error rate',
#  'SEAC',
#  'Precision',
#  'Recall',
#  'Go',
#  'NLP',
#  'MT',
#  'Whitening',
#  'Cran',
#  'IDE',
#  'Royal',
#  'CDF',
#  'ACL',
#  'European',
#  'ITRC',
#  'MLE',
#  'Multithreading',
#  'RDF',
#  'Planner',
#  'Russian',
#  'Vision',
#  'ELRA',
#  'Springer',
#  'Sensitivity',
#  'Android',
#  'Visualization',
#  'English',
#  'APL',
#  'Feature detection',
#  'American',
#  'Israeli',
#  'Python',
#  'Dutch',
#  'Puma',
#  'Assembly',
#  'Cross-validation',
#  'OMR',
#  'OCR',
#  'Searching',
#  'ML',
#  'MV',
#  'Map (disambiguation)',
#  'BS',
#  'MA',
#  'DAML',
#  'Oil (disambiguation)',
#  'NLU',
#  'NLG',
#  'PPV',
#  'NPV',
#  'For',
#  'IM',
#  'Bro',
#  'Alexa',
#  'Extraction',
#  'PDL',
#  'Regularization',
#  'Paramount',
#  'Sangaree',
#  'KRL',
#  'BMVC',
#  'LTM',
#  'Taxonomy',
#  'Locomotion',
#  'Scheme',
#  'AISB',
#  'DSP',
#  'Audio compression',
#  'Digital',
#  'MLM',
#  'Index',
#  'TN',
#  'TP',
#  'FP',
#  'FN',
#  'SMC',
#  'Bandwidth',
#  'Acoustic',
#  'Specificity',
#  'IAI',
#  'Learning theory',
#  'Cf',
#  'VLDB',
#  'NMT',
#  'CSR',
#  'KDD',
#  'ACM',
#  'AAAS',
#  'Indy',
#  'NMF',
#  'Freddy',
#  'School of Computer Science',
#  'RLS',
#  'Gate (disambiguation)',
#  'HMM',
#  'Access',
#  'SAS',
#  'EAS',
#  'Baxter',
#  'CGI',
#  'Prosody',
#  'NPS',
#  'HS',
#  'Control',
#  'Facial recognition',
#  'Word alignment',
#  'SMT',
#  'WSD',
#  'Roc',
#  'HLT',
#  'EM',
#  'FPR',
#  'FNR',
#  'Ale (disambiguation)',
#  'Ares (disambiguation)',
#  'ANN',
#  'ERM',
#  'Oscar',
#  'Rotary joint',
#  'ISWC',
#  'UAI',
#  'WSDM',
#  'German',
#  'Sully',
#  'First man or woman',
#  'ABA',
#  'FC',
#  'Kawasaki',
#  'MCC',
#  'Bea',
#  'NER',
#  'QA',
#  'LSI',
#  'Pascal',
#  'Cog',
#  'ASR',
#  'TTS',
#  'TPR',
#  'LCA',
#  'MARF',
#  'Animal (disambiguation)',
#  'HTK',
#  'Industrial',
#  'Tuning',
#  'WER',
#  'Mandarin',
#  'TNR',
#  'SPC',
#  'Kismet',
#  'VAL',
#  'Web',
#  'SFM',
#  'FIET',
#  'LPC',
#  'NTT',
#  'LDA',
#  'French',
#  'HAL',
#  'Loss',
#  'HCA',
#  'VUI',
#  'Nuance',
#  'Columbia',
#  'DAQ',
#  'WSI',
#  'AR',
#  'DAP',
#  'RET',
#  'Broadway',
#  'Caffe',
#  'CART',
#  'Orange',
#  'DCG',
#  'Voice recognition',
#  'Babel fish',
#  'Cling',
#  'Ex Machina',
#  'Hondo',
#  'CCA',
#  'CTC',
#  'LFP',
#  'LP',
#  '.net (disambiguation)',
#  'Summary',
#  'NIPS',
#  'Sigmoid',
#  'BBN',
#  'AGV',
#  'J48',
#  'ICCL',
#  'BER',
#  'Titan',
#  'Heartstone',
#  'Athletics',
#  'FRS',
#  'HFE2',
#  'PE',
#  'PP',
#  'GI',
#  'Gigantea',
#  'EPL',
#  'Voyager',
#  'Mimas',
#  'Roman',
#  'CLR',
#  'Angelina',
#  'Optica',
#  'SSC',
#  '4S',
#  'Eris',
#  'Mason',
#  'Mercury',
#  'IAP',
#  'Royal Victoria Hospital',
#  'PEP',
#  'OAA',
#  'ASN',
#  'PRO',
#  'ARG',
#  'Rhea',
#  'Triton',
#  'PRA',
#  'LH',
#  'JGI',
#  'WCS',
#  'Irreversible',
#  'No',
#  'BTX',
#  'IL-6',
#  'April (disambiguation)',
#  'New',
#  'Horizon (disambiguation)',
#  'FSH',
#  'HR',
#  'IPA',
#  'Caravan',
#  'Ceres',
#  'Quantum theory',
#  'JACS',
#  'Methone',
#  'ELKS',
#  'DPS',
#  'Ogilvie',
#  'Chinese Physics',
#  'DHPR',
#  'CAQ',
#  'The Patriot',
#  'NAA',
#  'IBA',
#  'Public Service Medal',
#  'Juno',
#  'Camilla',
#  'RN',
#  'EFR',
#  'PRR',
#  'Cassini',
#  'Solar',
#  'Lunar',
#  'PKA',
#  'Transcription',
#  'AIA',
#  'CDK',
#  'Meridian',
#  'Sinope',
#  'The End',
#  'Au',
#  'CPHA',
#  'PPA',
#  'A. fragilis',
#  'Fas',
#  'DR',
#  'Ras',
#  'IL-4',
#  'IL-2',
#  'Gymnasium',
#  'Sam',
#  'Environment',
#  'BES',
#  'MES',
#  'Doe',
#  'Lost',
#  'Sensorimotor',
#  'KIE',
#  'Royal Academy of Sciences',
#  'Flat Earth Society',
#  'Lunar distance',
#  'Ago',
#  'FT',
#  'ARA',
#  'Kronos',
#  'SDS',
#  'DOC',
#  'Cosmic',
#  'PHA',
#  'CpG',
#  'KOS',
#  'CCI',
#  'MCA',
#  'IPMS',
#  'BIH',
#  'Europa',
#  'Ganymede',
#  'Specimen',
#  'Tissue',
#  'Varices',
#  'Alveolus',
#  'Focus',
#  'Focal',
#  'Cerebral',
#  'Organ',
#  'Central vein',
#  'Nasal',
#  'Sinus',
#  'NCC',
#  'Suture',
#  'Lateral',
#  'Coronary',
#  'White cell',
#  'Cervical',
#  'Ventricle',
#  'Plaque',
#  'Oral',
#  'LC',
#  'Cortex',
#  'Serum',
#  'Limb',
#  'MNC',
#  'Atrium',
#  'GB',
#  'SCC',
#  'LCC',
#  'LE',
#  'Body',
#  'PLN',
#  'Lumen',
#  'Sacculus',
#  'Iris',
#  'ICB',
#  'Ciliary',
#  'Fragment',
#  'EC',
#  'Effector cell',
#  'Memory cell',
#  'Nuclear',
#  'Filament',
#  'FLS',
#  'Tubular',
#  'Interstitial',
#  'Trunk',
#  'Inner membrane',
#  'CNS',
#  'Esophageal',
#  'Colon',
#  'Conduit',
#  'Ra (disambiguation)',
#  'Ita',
#  'Rp',
#  'Left',
#  'Graft',
#  'Spine',
#  'Sera',
#  'WB',
#  'Sarcoid',
#  'WML',
#  'Brachial',
#  'Tympanum',
#  'Cochlear',
#  'Gut',
#  'Pelvic limb',
#  'Golgi',
#  'Orbital',
#  'Anterior horn',
#  'Primary',
#  'HCC',
#  'PSC',
#  'Cupula',
#  'Marrow',
#  'Flap',
#  'NSC',
#  'C6',
#  'WBC',
#  'Normal',
#  'Medulla',
#  'Mossy fiber',
#  'Synaptic',
#  'Egg (disambiguation)',
#  'LV',
#  'KS',
#  'Anal',
#  'DC',
#  'NK',
#  'Molar',
#  'Palmar',
#  'Radial',
#  'Oe',
#  'Section',
#  'Caudate',
#  'Front',
#  'Supplementary',
#  'Bolus',
#  'BAC',
#  'LGE',
#  'PD',
#  'Desaturation',
#  'VTE',
#  'Fits',
#  'Clumsy',
#  'Incontinence',
#  'Bipolar',
#  'Manic',
#  'TG',
#  'RS',
#  'Agitation',
#  'CM',
#  'VFD',
#  'Ich',
#  'Depressive',
#  'LIDS',
#  'Hypoxia',
#  'Ist',
#  'CHF',
#  'TD',
#  'Can',
#  'HT',
#  'Rigidity',
#  'ARF',
#  'Pa',
#  'Reye',
#  'VT',
#  'VF',
#  'SAH',
#  'RPN',
#  'Restless',
#  'Flushing',
#  'Edds',
#  'ALF',
#  'MDS',
#  'Dysrhythmia',
#  'Syncope',
#  'IBS',
#  'Hitt',
#  'EPS',
#  'AGC',
#  'MI',
#  'NMS',
#  'AF',
#  'Rupture',
#  'Di',
#  'Ari',
#  'AFL',
#  'AMI',
#  'Chill',
#  'All',
#  'MDP',
#  'Ie',
#  'CLE',
#  'GBM',
#  'Hit',
#  'Aki',
#  'MB',
#  'TIA',
#  'SRC',
#  'Burns',
#  'MM',
#  'HL',
#  'TLS',
#  'DVT (disambiguation)',
#  'Hyper',
#  'Thrush',
#  'Shock',
#  'Sclerosis',
#  'Pains',
#  'SS (disambiguation)',
#  'Tet',
#  'Fan',
#  'EP',
#  'Asa',
#  'PCP',
#  'DA',
#  'TAM',
#  'ATP',
#  'OC',
#  'Gaba',
#  'AAP',
#  'Dox',
#  'Lactate',
#  'La',
#  'Pan',
#  'AZT (disambiguation)',
#  'ACH',
#  'SRL',
#  'CSA',
#  'CPA',
#  'EE',
#  'GM',
#  'GSH',
#  'Li',
#  'AMB',
#  'OP',
#  'DFP',
#  'ADP',
#  'CR',
#  'BE',
#  'TRP',
#  'Ecstasy',
#  'Dex',
#  'ATO',
#  'Sodium citrate',
#  'Iva',
#  'CBZ',
#  ...]

# %%
len(to_remove)/len(terms)
# Out:
# 0.1231774174734632

# %%
dict_pagetitle_qid['German']
# Out:
# 'Q348514'

# %%
# remove disambiguation page from list entities
for key in to_remove:
    dict_pagetitle_qid.pop(key)

# %%
pd.DataFrame([(k,v) for k,v in dict_pagetitle_qid.items()]).to_csv(WIKIDATA_DICT, header=None, index=False, sep='\t')
